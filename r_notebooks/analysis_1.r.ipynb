# %% [markdown]
# # Fisher Test
#
# (Continue from analysis_2 after exporting from Python)
# NOTE: This is an R Jupyter notebook.

# %%
data_dir <-  file.path(getwd(), "..", "figures", "analysis_2", Sys.Date())

if (!dir.exists(data_dir)) {
# raise error if the directory does not exist
stmt <- paste0("The directory ", data_dir, " does not exist. Please run the analysis first.")
print(stmt)
stop(stmt)
} 

# load the csv
df <- read.csv(file.path(data_dir, "beta_blocker_effectiveness.csv"))
head(df)
# Out:
#   p_posedit_str False True X..Effective
# 1 Gly2337Val    1     10   90.90909
# 2 (Arg420Gln)   8     10   55.55556
# 3 (Met3978Ile)  7      7   50.00000
# 4 (Gly3946Ser)  3      3   50.00000
# 5 (Glu1724Lys)  3      2   40.00000
# 6 (Ser2246Leu)  5      3   37.50000

# %%
library(rstatix)

# %%
# create the table from the dataframe - only need 
# the p_posedit_str column (this will be the row names)
# False column (not effective)
# True column (effective)
df_test <- df[, c("p_posedit_str", "False", "True")]
# set the row names
rownames(df_test) <- df_test$p_posedit_str
# remove the p_posedit_str column
df_test <- df_test[, -1]
df_test
# Out:
#              False True
# Gly2337Val    1    10
# (Arg420Gln)   8    10
# (Met3978Ile)  7     7
# (Gly3946Ser)  3     3
# (Glu1724Lys)  3     2
# (Ser2246Leu)  5     3
# (Arg2401His)  4     2
# (Arg420Trp)  12     5
# (Cys2277Arg)  6     2
# (Ser4124Gly)  6     0

# %% [markdown]
# Run fisher test on the data to see if there is a significant difference between the 10 conditions

# %%
row_wise_fisher_test(xtab=df_test, p.adjust.method = "fdr")
# Out:
#    group        n  p       p.adj  p.adj.signif
# 1  Gly2337Val   99 0.00209 0.0209 *
# 2  (Arg420Gln)  99 0.30900 0.6180 ns
# 3  (Met3978Ile) 99 0.77400 0.9680 ns
# 4  (Gly3946Ser) 99 1.00000 1.0000 ns
# 5  (Glu1724Lys) 99 1.00000 1.0000 ns
# 6  (Ser2246Leu) 99 0.73000 0.9680 ns
# 7  (Arg2401His) 99 0.69000 0.9680 ns
# 8  (Arg420Trp)  99 0.19200 0.6180 ns
# 9  (Cys2277Arg) 99 0.29400 0.6180 ns
# 10 (Ser4124Gly) 99 0.03220 0.1610 ns

# %%
pairwise_fisher_test(x=df_test, p.adjust.method = "fdr")
# Out:
#    group1       group2       n  p        p.adj  p.adj.signif
# 1  Gly2337Val   (Arg420Gln)  29 0.095900 0.4040 ns
# 2  Gly2337Val   (Met3978Ile) 25 0.042100 0.2710 ns
# 3  Gly2337Val   (Gly3946Ser) 17 0.098700 0.4040 ns
# 4  Gly2337Val   (Glu1724Lys) 16 0.063200 0.3160 ns
# 5  Gly2337Val   (Ser2246Leu) 19 0.040800 0.2710 ns
# 6  Gly2337Val   (Arg2401His) 17 0.027600 0.2480 ns
# 7  Gly2337Val   (Arg420Trp)  28 0.002080 0.0468 *
# 8  Gly2337Val   (Cys2277Arg) 19 0.006270 0.0941 ns
# 9  Gly2337Val   (Ser4124Gly) 17 0.000566 0.0255 *
# 10 (Arg420Gln)  (Met3978Ile) 32 1.000000 1.0000 ns
# 11 (Arg420Gln)  (Gly3946Ser) 24 1.000000 1.0000 ns
# 12 (Arg420Gln)  (Glu1724Lys) 23 0.640000 1.0000 ns
# 13 (Arg420Gln)  (Ser2246Leu) 26 0.673000 1.0000 ns
# 14 (Arg420Gln)  (Arg2401His) 24 0.640000 1.0000 ns
# 15 (Arg420Gln)  (Arg420Trp)  35 0.176000 0.5850 ns
# 16 (Arg420Gln)  (Cys2277Arg) 26 0.216000 0.6080 ns
# 17 (Arg420Gln)  (Ser4124Gly) 24 0.023900 0.2480 ns
# 18 (Met3978Ile) (Gly3946Ser) 20 1.000000 1.0000 ns
# 19 (Met3978Ile) (Glu1724Lys) 19 1.000000 1.0000 ns
# 20 (Met3978Ile) (Ser2246Leu) 22 0.675000 1.0000 ns
# 21 (Met3978Ile) (Arg2401His) 20 0.642000 1.0000 ns
# 22 (Met3978Ile) (Arg420Trp)  31 0.288000 0.7200 ns
# 23 (Met3978Ile) (Cys2277Arg) 22 0.380000 0.9000 ns
# 24 (Met3978Ile) (Ser4124Gly) 20 0.051500 0.2900 ns
# 25 (Gly3946Ser) (Glu1724Lys) 11 1.000000 1.0000 ns
# 26 (Gly3946Ser) (Ser2246Leu) 14 1.000000 1.0000 ns
# 27 (Gly3946Ser) (Arg2401His) 12 1.000000 1.0000 ns
# 28 (Gly3946Ser) (Arg420Trp)  23 0.621000 1.0000 ns
# 29 (Gly3946Ser) (Cys2277Arg) 14 0.580000 1.0000 ns
# 30 (Gly3946Ser) (Ser4124Gly) 12 0.182000 0.5850 ns
# 31 (Glu1724Lys) (Ser2246Leu) 13 1.000000 1.0000 ns
# 32 (Glu1724Lys) (Arg2401His) 11 1.000000 1.0000 ns
# 33 (Glu1724Lys) (Arg420Trp)  22 1.000000 1.0000 ns
# 34 (Glu1724Lys) (Cys2277Arg) 13 1.000000 1.0000 ns
# 35 (Glu1724Lys) (Ser4124Gly) 11 0.182000 0.5850 ns
# 36 (Ser2246Leu) (Arg2401His) 14 1.000000 1.0000 ns
# 37 (Ser2246Leu) (Arg420Trp)  25 1.000000 1.0000 ns
# 38 (Ser2246Leu) (Cys2277Arg) 16 1.000000 1.0000 ns
# 39 (Ser2246Leu) (Ser4124Gly) 14 0.209000 0.6080 ns
# 40 (Arg2401His) (Arg420Trp)  23 1.000000 1.0000 ns
# 41 (Arg2401His) (Cys2277Arg) 14 1.000000 1.0000 ns
# 42 (Arg2401His) (Ser4124Gly) 12 0.455000 1.0000 ns
# 43 (Arg420Trp)  (Cys2277Arg) 25 1.000000 1.0000 ns
# 44 (Arg420Trp)  (Ser4124Gly) 23 0.272000 0.7200 ns
# 45 (Cys2277Arg) (Ser4124Gly) 14 0.473000 1.0000 ns

# %% [markdown]
# # Validate flecainide usage among variants
#
# Try to see if this statement is actually true after adding the FDR correction:
# When comparing therapeutic strategies between the most common mutations, a significantly greater proportion of those with the R420W (70.6%) required a poly-pharmaceutical approach compared to R420Q (8.3%, p = <0.001) in the setting of similar ICD usage.

# %%
fisher_flec <- read.csv(file.path(data_dir, "flecainide_fisher.csv"))
head(fisher_flec)
# Out:
#   p_posedit_str Flecainide_and_beta_blocker beta_blocker_only Total
# 1 (Arg420Gln)    2                          22                24
# 2 (Arg420Trp)   12                           5                17
# 3 (Gly357Ser)    0                          94                94
# 4 (Gly3946Ser)   2                           9                11
# 5 Gly2337Val     0                          21                21

# %%
fisher_flec_test <- fisher_flec[, c("p_posedit_str",
                                     "Flecainide_and_beta_blocker",
                                     "beta_blocker_only")]
rownames(fisher_flec_test) <- fisher_flec_test$p_posedit_str
fisher_flec_test <- fisher_flec_test[, -1]
fisher_flec_test
# Out:
#              Flecainide_and_beta_blocker beta_blocker_only
# (Arg420Gln)   2                          22
# (Arg420Trp)  12                           5
# (Gly357Ser)   0                          94
# (Gly3946Ser)  2                           9
# Gly2337Val    0                          21

# %%
# run the fisher test
row_wise_fisher_test(xtab=fisher_flec_test, p.adjust.method = "fdr")
# Out:
#   group        n   p        p.adj    p.adj.signif
# 1 (Arg420Gln)  167 1.00e+00 1.00e+00 ns
# 2 (Arg420Trp)  167 1.52e-11 7.60e-11 ****
# 3 (Gly357Ser)  167 6.33e-07 1.58e-06 ****
# 4 (Gly3946Ser) 167 2.84e-01 3.55e-01 ns
# 5 Gly2337Val   167 2.26e-01 3.55e-01 ns

# %%
pairwise_fisher_test(x=fisher_flec_test, p.adjust.method = "fdr")
# Out:
#    group1       group2       n   p        p.adj    p.adj.signif
# 1  (Arg420Gln)  (Arg420Trp)   41 5.01e-05 1.67e-04 ***
# 2  (Arg420Gln)  (Gly357Ser)  118 4.00e-02 6.67e-02 ns
# 3  (Arg420Gln)  (Gly3946Ser)  35 5.75e-01 6.39e-01 ns
# 4  (Arg420Gln)  Gly2337Val    45 4.91e-01 6.14e-01 ns
# 5  (Arg420Trp)  (Gly357Ser)  111 1.57e-12 1.57e-11 ****
# 6  (Arg420Trp)  (Gly3946Ser)  28 1.83e-02 3.66e-02 *
# 7  (Arg420Trp)  Gly2337Val    38 2.29e-06 1.14e-05 ****
# 8  (Gly357Ser)  (Gly3946Ser) 105 1.01e-02 2.52e-02 *
# 9  (Gly357Ser)  Gly2337Val   115 1.00e+00 1.00e+00 ns
# 10 (Gly3946Ser) Gly2337Val    32 1.11e-01 1.59e-01 ns

# %% [markdown]
# # Validate ICD usage among variants

# %%
fisher_icd <- read.csv(file.path(data_dir, "icd_fisher.csv"))
head(fisher_icd)
# Out:
#   p_posedit_str ICD_and_beta_blocker beta_blocker_only Total
# 1 (Arg420Gln)   13                   11                24
# 2 (Arg420Trp)    5                   12                17
# 3 (Gly357Ser)    1                   93                94
# 4 (Gly3946Ser)   1                   10                11
# 5 Gly2337Val     1                   20                21

# %%
# same for icd
fisher_icd_test <- fisher_icd[, c("p_posedit_str", "ICD_and_beta_blocker",
                                   "beta_blocker_only")]
rownames(fisher_icd_test) <- fisher_icd_test$p_posedit_str
fisher_icd_test <- fisher_icd_test[, -1]
fisher_icd_test
# Out:
#              ICD_and_beta_blocker beta_blocker_only
# (Arg420Gln)  13                   11
# (Arg420Trp)   5                   12
# (Gly357Ser)   1                   93
# (Gly3946Ser)  1                   10
# Gly2337Val    1                   20

# %%
# run for icd
row_wise_fisher_test(xtab=fisher_icd_test, p.adjust.method = "fdr")
# Out:
#   group        n   p        p.adj    p.adj.signif
# 1 (Arg420Gln)  167 3.71e-08 1.86e-07 ****
# 2 (Arg420Trp)  167 4.35e-02 7.25e-02 ns
# 3 (Gly357Ser)  167 1.66e-07 4.15e-07 ****
# 4 (Gly3946Ser) 167 1.00e+00 1.00e+00 ns
# 5 Gly2337Val   167 4.78e-01 5.97e-01 ns

# %%
pairwise_fisher_test(x=fisher_icd_test, p.adjust.method = "fdr")
# Out:
#    group1       group2       n   p        p.adj    p.adj.signif
# 1  (Arg420Gln)  (Arg420Trp)   41 2.01e-01 2.87e-01 ns
# 2  (Arg420Gln)  (Gly357Ser)  118 4.53e-10 4.53e-09 ****
# 3  (Arg420Gln)  (Gly3946Ser)  35 2.33e-02 5.82e-02 ns
# 4  (Arg420Gln)  Gly2337Val    45 3.56e-04 1.19e-03 **
# 5  (Arg420Trp)  (Gly357Ser)  111 2.62e-04 1.19e-03 **
# 6  (Arg420Trp)  (Gly3946Ser)  28 3.55e-01 3.94e-01 ns
# 7  (Arg420Trp)  Gly2337Val    38 7.12e-02 1.42e-01 ns
# 8  (Gly357Ser)  (Gly3946Ser) 105 1.99e-01 2.87e-01 ns
# 9  (Gly357Ser)  Gly2337Val   115 3.33e-01 3.94e-01 ns
# 10 (Gly3946Ser) Gly2337Val    32 1.00e+00 1.00e+00 ns

# %% [markdown]
# # Treatment Effectiveness (Other than Beta Blockers)

# %%
f_effective <- read.csv(file.path(data_dir, "flecainide_effectiveness.csv"))
head(f_effective)
# Out:
#   p_posedit_str Effective Ineffective Total
# 1 (Arg420Gln)    0        2            2
# 2 (Arg420Trp)   11        1           12
# 3 (Glu1724Lys)   1        2            3
# 4 (Gly3946Ser)   2        0            2
# 5 (Met3978Ile)   4        4            8

# %%
icd_effective <- read.csv(file.path(data_dir, "icd_effectiveness.csv"))
head(icd_effective)
# Out:
#   p_posedit_str Effective Ineffective Total
# 1 (Arg420Gln)   4         5           9
# 2 (Arg420Trp)   3         1           4
# 3 (Arg4497Cys)  1         0           1
# 4 (Arg4959Gln)  2         1           3
# 5 (Glu1724Lys)  1         0           1
# 6 (Gly357Ser)   1         0           1

# %%
f_effective_test <- f_effective[, c("p_posedit_str", "Effective", "Ineffective")]
rownames(f_effective_test) <- f_effective_test$p_posedit_str
f_effective_test <- f_effective_test[, -1]
f_effective_test
# Out:
#              Effective Ineffective
# (Arg420Gln)   0        2
# (Arg420Trp)  11        1
# (Glu1724Lys)  1        2
# (Gly3946Ser)  2        0
# (Met3978Ile)  4        4

# %%
icd_effective_test <- icd_effective[, c("p_posedit_str", "Effective", "Ineffective")]
rownames(icd_effective_test) <- icd_effective_test$p_posedit_str
icd_effective_test <- icd_effective_test[, -1]
icd_effective_test
# Out:
#                Effective Ineffective
# (Arg420Gln)    4         5
# (Arg420Trp)    3         1
# (Arg4497Cys)   1         0
# (Arg4959Gln)   2         1
# (Glu1724Lys)   1         0
# (Gly357Ser)    1         0
# (Gly3946Ser)   0         1
# (Met3978Ile)   1         4
# Asn57_Gly91del 2         0
# Gly2337Val     1         0

# %%
# run the fisher test
row_wise_fisher_test(xtab=f_effective_test, p.adjust.method = "fdr")
# Out:
#   group        n  p      p.adj p.adj.signif
# 1 (Arg420Gln)  27 0.1030 0.258 ns
# 2 (Arg420Trp)  27 0.0192 0.096 ns
# 3 (Glu1724Lys) 27 0.2500 0.417 ns
# 4 (Gly3946Ser) 27 0.5380 0.538 ns
# 5 (Met3978Ile) 27 0.3750 0.469 ns

# %%
# run the pairwise fisher test
pairwise_fisher_test(x=f_effective_test, p.adjust.method = "fdr")
# Out:
#    group1       group2       n  p      p.adj p.adj.signif
# 1  (Arg420Gln)  (Arg420Trp)  14 0.0330 0.330 ns
# 2  (Arg420Gln)  (Glu1724Lys)  5 1.0000 1.000 ns
# 3  (Arg420Gln)  (Gly3946Ser)  4 0.3330 0.667 ns
# 4  (Arg420Gln)  (Met3978Ile) 10 0.4670 0.667 ns
# 5  (Arg420Trp)  (Glu1724Lys) 15 0.0813 0.363 ns
# 6  (Arg420Trp)  (Gly3946Ser) 14 1.0000 1.000 ns
# 7  (Arg420Trp)  (Met3978Ile) 20 0.1090 0.363 ns
# 8  (Glu1724Lys) (Gly3946Ser)  5 0.4000 0.667 ns
# 9  (Glu1724Lys) (Met3978Ile) 11 1.0000 1.000 ns
# 10 (Gly3946Ser) (Met3978Ile) 10 0.4670 0.667 ns

# %%
row_wise_fisher_test(xtab=icd_effective_test, p.adjust.method = "fdr")
# Out:
#    group          n  p     p.adj p.adj.signif
# 1  (Arg420Gln)    28 0.432 1     ns
# 2  (Arg420Trp)    28 0.613 1     ns
# 3  (Arg4497Cys)   28 1.000 1     ns
# 4  (Arg4959Gln)   28 1.000 1     ns
# 5  (Glu1724Lys)   28 1.000 1     ns
# 6  (Gly357Ser)    28 1.000 1     ns
# 7  (Gly3946Ser)   28 0.429 1     ns
# 8  (Met3978Ile)   28 0.133 1     ns
# 9  Asn57_Gly91del 28 0.492 1     ns
# 10 Gly2337Val     28 1.000 1     ns

# %%
pairwise_fisher_test(x=icd_effective_test, p.adjust.method = "fdr")
# Out:
#    group1         group2         n  p     p.adj p.adj.signif
# 1  (Arg420Gln)    (Arg420Trp)    13 0.559 1     ns
# 2  (Arg420Gln)    (Arg4497Cys)   10 1.000 1     ns
# 3  (Arg420Gln)    (Arg4959Gln)   12 1.000 1     ns
# 4  (Arg420Gln)    (Glu1724Lys)   10 1.000 1     ns
# 5  (Arg420Gln)    (Gly357Ser)    10 1.000 1     ns
# 6  (Arg420Gln)    (Gly3946Ser)   10 1.000 1     ns
# 7  (Arg420Gln)    (Met3978Ile)   14 0.580 1     ns
# 8  (Arg420Gln)    Asn57_Gly91del 11 0.455 1     ns
# 9  (Arg420Gln)    Gly2337Val     10 1.000 1     ns
# 10 (Arg420Trp)    (Arg4497Cys)    5 1.000 1     ns
# 11 (Arg420Trp)    (Arg4959Gln)    7 1.000 1     ns
# 12 (Arg420Trp)    (Glu1724Lys)    5 1.000 1     ns
# 13 (Arg420Trp)    (Gly357Ser)     5 1.000 1     ns
# 14 (Arg420Trp)    (Gly3946Ser)    5 0.400 1     ns
# 15 (Arg420Trp)    (Met3978Ile)    9 0.206 1     ns
# 16 (Arg420Trp)    Asn57_Gly91del  6 1.000 1     ns
# 17 (Arg420Trp)    Gly2337Val      5 1.000 1     ns
# 18 (Arg4497Cys)   (Arg4959Gln)    4 1.000 1     ns
# 19 (Arg4497Cys)   (Glu1724Lys)    2 1.000 1     ns
# 20 (Arg4497Cys)   (Gly357Ser)     2 1.000 1     ns
# 21 (Arg4497Cys)   (Gly3946Ser)    2 1.000 1     ns
# 22 (Arg4497Cys)   (Met3978Ile)    6 0.333 1     ns
# 23 (Arg4497Cys)   Asn57_Gly91del  3 1.000 1     ns
# 24 (Arg4497Cys)   Gly2337Val      2 1.000 1     ns
# 25 (Arg4959Gln)   (Glu1724Lys)    4 1.000 1     ns
# 26 (Arg4959Gln)   (Gly357Ser)     4 1.000 1     ns
# 27 (Arg4959Gln)   (Gly3946Ser)    4 1.000 1     ns
# 28 (Arg4959Gln)   (Met3978Ile)    8 0.464 1     ns
# 29 (Arg4959Gln)   Asn57_Gly91del  5 1.000 1     ns
# 30 (Arg4959Gln)   Gly2337Val      4 1.000 1     ns
# 31 (Glu1724Lys)   (Gly357Ser)     2 1.000 1     ns
# 32 (Glu1724Lys)   (Gly3946Ser)    2 1.000 1     ns
# 33 (Glu1724Lys)   (Met3978Ile)    6 0.333 1     ns
# 34 (Glu1724Lys)   Asn57_Gly91del  3 1.000 1     ns
# 35 (Glu1724Lys)   Gly2337Val      2 1.000 1     ns
# 36 (Gly357Ser)    (Gly3946Ser)    2 1.000 1     ns
# 37 (Gly357Ser)    (Met3978Ile)    6 0.333 1     ns
# 38 (Gly357Ser)    Asn57_Gly91del  3 1.000 1     ns
# 39 (Gly357Ser)    Gly2337Val      2 1.000 1     ns
# 40 (Gly3946Ser)   (Met3978Ile)    6 1.000 1     ns
# 41 (Gly3946Ser)   Asn57_Gly91del  3 0.333 1     ns
# 42 (Gly3946Ser)   Gly2337Val      2 1.000 1     ns
# 43 (Met3978Ile)   Asn57_Gly91del  7 0.143 1     ns
# 44 (Met3978Ile)   Gly2337Val      6 0.333 1     ns
# 45 Asn57_Gly91del Gly2337Val      3 1.000 1     ns
