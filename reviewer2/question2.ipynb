# %% [markdown]
# # Reviewer 2. Question 2.
#
# Patients with CPVT frequently experience atrial tachyarrhythmias, which can lead to inappropriate ICD therapy and cerebral infarction. Both events could worsen the prognosis of thsese patients. Are there any hotspots associated with occurrence of atrial tachyarrhythmias?

# %%
import json

import pandas as pd
import numpy as np

# %%
from analysis.database import get_config

config = get_config()

# %%
from pathlib import Path

data_all = pd.read_excel(
    Path.cwd().parent / "data" / f"individual_all_data-{config.version}.xlsx")

columns = [
    "individual_id",
    "Catecholaminergic polymorphic ventricular tachycardia 1",
    "hgvs_string",
    "Atrial tachycardia",
    "exons",
    "structure_domains",
    "publication_id",
    "title",
    "doi"
]

data = data_all[columns].copy()
data = data[
    data["Catecholaminergic polymorphic ventricular tachycardia 1"] == 1]
data = data[data["Atrial tachycardia"] == 1]
data.head()
# Out:
#      individual_id  Catecholaminergic polymorphic ventricular tachycardia 1  \
# 3                4                                                1.0
# 27              28                                                1.0
# 32              33                                                1.0
# 315            318                                                1.0
# 316            319                                                1.0
#
#                 hgvs_string  Atrial tachycardia      exons  \
# 3    NM_001035.3:c.14174A>G                 1.0  [99, 100)
# 27   NM_001035.3:c.13933T>A                 1.0   [96, 97)
# 32   NM_001035.3:c.13933T>A                 1.0   [96, 97)
# 315   NM_001035.3:c.1259G>A                 1.0   [14, 15)
# 316   NM_001035.3:c.1259G>A                 1.0   [14, 15)
#
#                                      structure_domains  publication_id  \
# 3    [{'structure_id': 23, 'structure_domain': 'Tra...               4
# 27   [{'structure_id': 19, 'structure_domain': 'Act...              28
# 32   [{'structure_id': 19, 'structure_domain': 'Act...              28
# 315  [{'structure_id': 3, 'structure_domain': 'N-te...             283
# 316  [{'structure_id': 3, 'structure_domain': 'N-te...             283
#
#                                                  title  \
# 3    Genetic Background of Catecholaminergic Polymo...
# 27   Genetic characterization of familial CPVT afte...
# 32   Genetic characterization of familial CPVT afte...
# 315  Non-ventricular, Clinical, and Functional Feat...
# 316  Non-ventricular, Clinical, and Functional Feat...
#
#                            doi
# 3     10.1253/circj.cj-12-1460
# 27    10.1177/1099800409333369
# 32    10.1177/1099800409333369
# 315  10.1016/j.rec.2014.04.023
# 316  10.1016/j.rec.2014.04.023

# %%
data.shape
# Out:
# (23, 9)

# %%
# print how many has nan hgvs strings
print("nan by hgvs", data["hgvs_string"].isna().sum())
print("nan by exons", data["exons"].isna().sum())
print("nan by structure_domains", data["structure_domains"].isna().sum())
# Out:
# nan by hgvs 0
# nan by exons 3
# nan by structure_domains 2

# %%
print("unique hgvs", data["hgvs_string"].unique().shape)
# Out:
# unique hgvs (14,)

# %%
data["hgvs_string"].unique()
# Out:
# array(['NM_001035.3:c.14174A>G', 'NM_001035.3:c.13933T>A',
#        'NM_001035.3:c.1259G>A', 'NM_001035.3:c.12476A>C',
#        'NM_001035.3:c.14251A>C', 'NM_001035.3:c.14600T>C',
#        'NM_001035.3:c.13735C>T', 'NM_001035.3:c.5128C>T',
#        'NM_001035.3:c.11836G>A', 'NP_001026.2:p.Gly3946Ala',
#        'NM_001035.3:c.14553C>A', 'NM_001035.3:c.13892A>T',
#        'NM_001035.3:c.12271G>A', 'exon 3 deletion'], dtype=object)

# %%
fig_dir = Path.cwd().parent / "figures"

if not fig_dir.exists():
    fig_dir.mkdir()
    print("Created directory:", fig_dir)
else:
    print("Directory exists:", fig_dir)
# Out:
# Directory exists: /Users/alex/dev/marks/2024/cpvt_database_analysis/figures

# %%
data["exons_range"] = data["exons"].str.replace("[", "").str.replace(")",
                                                                     "").str.split(
    ", ").astype(object).apply(
    lambda x: [int(i) for i in x] if np.any(pd.notna(x)) else np.nan)
data["exon_start"] = data["exons_range"].apply(
    lambda x: x[0] if np.any(pd.notna(x)) else np.nan)
data["exon_end"] = data["exons_range"].apply(
    lambda x: x[1] - 1 if np.any(pd.notna(x)) else np.nan)
data = data[data["Atrial tachycardia"] == 1]
data = data[data["exon_start"].notna()]

data[[
    "hgvs_string",
    "title",
    "publication_id",
    "exon_start",
    "doi",
]].sort_values("exon_start")
# Out:
#                  hgvs_string  \
# 322    NM_001035.3:c.1259G>A
# 315    NM_001035.3:c.1259G>A
# 316    NM_001035.3:c.1259G>A
# 317    NM_001035.3:c.1259G>A
# 318    NM_001035.3:c.1259G>A
# 319    NM_001035.3:c.1259G>A
# 320    NM_001035.3:c.1259G>A
# 804    NM_001035.3:c.5128C>T
# 843   NM_001035.3:c.11836G>A
# 482   NM_001035.3:c.12476A>C
# 1258  NM_001035.3:c.12271G>A
# 785   NM_001035.3:c.13735C>T
# 1188  NM_001035.3:c.13892A>T
# 32    NM_001035.3:c.13933T>A
# 27    NM_001035.3:c.13933T>A
# 723   NM_001035.3:c.14251A>C
# 3     NM_001035.3:c.14174A>G
# 1100  NM_001035.3:c.14553C>A
# 743   NM_001035.3:c.14600T>C
# 744   NM_001035.3:c.14600T>C
#
#                                                   title  publication_id  \
# 322   Non-ventricular, Clinical, and Functional Feat...             283
# 315   Non-ventricular, Clinical, and Functional Feat...             283
# 316   Non-ventricular, Clinical, and Functional Feat...             283
# 317   Non-ventricular, Clinical, and Functional Feat...             283
# 318   Non-ventricular, Clinical, and Functional Feat...             283
# 319   Non-ventricular, Clinical, and Functional Feat...             283
# 320   Non-ventricular, Clinical, and Functional Feat...             283
# 804   Catecholaminergic polymorphic ventricular tach...             810
# 843   Genetic Background of Catecholaminergic Polymo...               4
# 482   A novel RyR2 mutation in a 2-year-old baby pre...             486
# 1258  Complex atrial arrhythmias as first manifestat...            1267
# 785   Postmortem genetic testing of the ryanodine re...             472
# 1188  RYR2 sequencing reveals novel missense mutatio...              93
# 32    Genetic characterization of familial CPVT afte...              28
# 27    Genetic characterization of familial CPVT afte...              28
# 723   Genetic Background of Catecholaminergic Polymo...               4
# 3     Genetic Background of Catecholaminergic Polymo...               4
# 1100  Nationwide experience of catecholaminergic pol...              84
# 743   Nationwide experience of catecholaminergic pol...              84
# 744   The Complexity of Pediatric Multifocal Atrial ...             750
#
#       exon_start                           doi
# 322         14.0     10.1016/j.rec.2014.04.023
# 315         14.0     10.1016/j.rec.2014.04.023
# 316         14.0     10.1016/j.rec.2014.04.023
# 317         14.0     10.1016/j.rec.2014.04.023
# 318         14.0     10.1016/j.rec.2014.04.023
# 319         14.0     10.1016/j.rec.2014.04.023
# 320         14.0     10.1016/j.rec.2014.04.023
# 804         37.0            10.1002/joa3.12280
# 843         88.0      10.1253/circj.cj-12-1460
# 482         90.0   10.1016/j.hrthm.2014.04.037
# 1258        90.0     10.1017/S1047951113001091
# 785         94.0     10.1007/s00414-011-0658-2
# 1188        95.0  10.1371/journal.pone.0101059
# 32          96.0      10.1177/1099800409333369
# 27          96.0      10.1177/1099800409333369
# 723         99.0      10.1253/circj.cj-12-1460
# 3           99.0      10.1253/circj.cj-12-1460
# 1100       101.0  10.1136/heartjnl-2016-310509
# 743        102.0  10.1136/heartjnl-2016-310509
# 744        102.0         10.4070/kcj.2017.0179

# %%
data["hgvs_string"].unique().shape
# Out:
# (12,)

# %%
# group by exon start
counts_at = data.groupby("exon_start").size().rename("count").sort_values(
    ascending=False)
counts_at.head()
# Out:
# exon_start
# 14.0     7
# 90.0     2
# 96.0     2
# 99.0     2
# 102.0    2
# Name: count, dtype: int64

# %%
counts_at[14]
# Out:
# 7

# %%
14 in counts_at
# Out:
# True

# %%
counts_all = pd.DataFrame(counts_at)
counts_all["exon_start"] = counts_all.index.astype(int)
counts_all.set_index("exon_start", inplace=True)
counts_all
# Out:
#             count
# exon_start
# 14              7
# 90              2
# 96              2
# 99              2
# 102             2
# 37              1
# 88              1
# 94              1
# 95              1
# 101             1

# %%
counts_all["count"].sum()
# Out:
# 20

# %%
import matplotlib.pyplot as plt
import seaborn as sns

with plt.rc_context({
    'font.size': 14,
    'figure.figsize': (8, 5),
}):
    sns.barplot(x="exon_start", y="count", data=counts_all)
    # plt.xticks(rotation=90)
    plt.title("Number of patients with Atrial tachycardia by Exon")
    plt.xlabel("Exon")
    plt.ylabel("Number of patients")

    locs, labels = plt.yticks()
    plt.yticks(np.arange(0, int(counts_all["count"].max()) + 1, 1))

    plt.tight_layout()
    plt.savefig(
        fig_dir / "reviewer2.question2.at_individuals_by_exon_location.png")
    plt.show()

# %%
var_counts = data.drop_duplicates("hgvs_string").groupby(
    "exon_start").size().rename("count").sort_values(ascending=False)

var_counts.head()
# Out:
# exon_start
# 90.0    2
# 99.0    2
# 14.0    1
# 37.0    1
# 88.0    1
# Name: count, dtype: int64

# %%
var_counts.sum()
# Out:
# 12

# %%
data[data["Atrial tachycardia"] == 1]["hgvs_string"].unique().shape
# Out:
# (12,)

# %%
variant_counts = pd.DataFrame(var_counts)
variant_counts["exon_start"] = variant_counts.index.astype(int)
variant_counts.set_index("exon_start", inplace=True)
variant_counts
# Out:
#             count
# exon_start
# 90              2
# 99              2
# 14              1
# 37              1
# 88              1
# 94              1
# 95              1
# 96              1
# 101             1
# 102             1

# %%
with plt.rc_context({
    'font.size': 14,
    'figure.figsize': (8, 5),
}):
    sns.barplot(x="exon_start", y="count", data=variant_counts)
    # plt.xticks(rotation=90)
    plt.title("Number of unique variants with Atrial tachycardia by Exon")
    plt.xlabel("Exon")
    plt.ylabel("Number of unique variants")

    # make the y ticks integers
    locs, labels = plt.yticks()
    plt.yticks(np.arange(0, int(variant_counts["count"].max()) + 1, 1))

    plt.tight_layout()
    plt.savefig(
        fig_dir / "reviewer2.question2.at_variants_by_exon_location.png")
    plt.show()

# %%
sorted(counts_at.index.tolist())
# Out:
# [14.0, 37.0, 88.0, 90.0, 94.0, 95.0, 96.0, 99.0, 101.0, 102.0]

# %% [markdown]
# # Structure

# %%
data.head()
# Out:
#      individual_id  Catecholaminergic polymorphic ventricular tachycardia 1  \
# 3                4                                                1.0
# 27              28                                                1.0
# 32              33                                                1.0
# 315            318                                                1.0
# 316            319                                                1.0
#
#                 hgvs_string  Atrial tachycardia      exons  \
# 3    NM_001035.3:c.14174A>G                 1.0  [99, 100)
# 27   NM_001035.3:c.13933T>A                 1.0   [96, 97)
# 32   NM_001035.3:c.13933T>A                 1.0   [96, 97)
# 315   NM_001035.3:c.1259G>A                 1.0   [14, 15)
# 316   NM_001035.3:c.1259G>A                 1.0   [14, 15)
#
#                                      structure_domains  publication_id  \
# 3    [{'structure_id': 23, 'structure_domain': 'Tra...               4
# 27   [{'structure_id': 19, 'structure_domain': 'Act...              28
# 32   [{'structure_id': 19, 'structure_domain': 'Act...              28
# 315  [{'structure_id': 3, 'structure_domain': 'N-te...             283
# 316  [{'structure_id': 3, 'structure_domain': 'N-te...             283
#
#                                                  title  \
# 3    Genetic Background of Catecholaminergic Polymo...
# 27   Genetic characterization of familial CPVT afte...
# 32   Genetic characterization of familial CPVT afte...
# 315  Non-ventricular, Clinical, and Functional Feat...
# 316  Non-ventricular, Clinical, and Functional Feat...
#
#                            doi exons_range  exon_start  exon_end
# 3     10.1253/circj.cj-12-1460   [99, 100]        99.0      99.0
# 27    10.1177/1099800409333369    [96, 97]        96.0      96.0
# 32    10.1177/1099800409333369    [96, 97]        96.0      96.0
# 315  10.1016/j.rec.2014.04.023    [14, 15]        14.0      14.0
# 316  10.1016/j.rec.2014.04.023    [14, 15]        14.0      14.0

# %%
# domains
domains_df = pd.read_csv("../analysis/data_commit/ryr2_subdomains.csv")
domains_df
# Out:
#    domains subdomains subdomain_precedence
# 0      NTD      NTD-A                  NaN
# 1     SPRY      NTD-B                  NaN
# 2     JSol       NSol                  NaN
# 3     BSol      SPRY1                  NaN
# 4     SCLP      SPRY2                  NaN
# 5     CSol      SPRY3                  NaN
# 6     TaF       RY1&2                  NaN
# 7       TM       JSol                  NaN
# 8      CTD      BSol1                  NaN
# 9      NaN      BSol2                  NaN
# 10     NaN      BSol3                  NaN
# 11     NaN      RY3&4                  NaN
# 12     NaN       SCLP                  NaN
# 13     NaN       CSol                  NaN
# 14     NaN      EF1&2                 True
# 15     NaN        TaF                  NaN
# 16     NaN         TM                  NaN
# 17     NaN         Sx                 True
# 18     NaN       pVSD                 True
# 19     NaN       Pore                 True
# 20     NaN        CTD                  NaN
# 21     NaN        ZnF                 True

# %%
def find_domain(structure_domain: list[dict], domains: set[str]):
    if not structure_domain:
        return None

    in_domains = []
    for d in structure_domain:
        # example value: [{'structure_id': 27, 'structure_domain': 'C-terminal domain ', 'structure_domain_symbol': 'CTD'}, {'structure_id': 19, 'structure_domain': 'Activation core and channel', 'structure_domain_symbol': None}]
        domain_symbol = d["structure_domain_symbol"]

        if domain_symbol is None or pd.isna(domain_symbol):
            continue

        if domain_symbol in domains:
            in_domains.append(domain_symbol)

    if len(in_domains) == 0:
        print(
            f"No domains found: {structure_domain}. Setting to full name if structure_domain is length 1."
        )
        return return_first_full_domain_name(structure_domain)

    if len(in_domains) == 1:
        return in_domains[0]

    raise ValueError(f"Multiple domains found: {in_domains}")


def find_subdomain(
        structure_domain: list[dict], subdomain_with_precedence: dict[str, bool]
):
    if not structure_domain:
        return None

    in_subdomains = []
    for d in structure_domain:

        domain_symbol = d["structure_domain_symbol"]

        if domain_symbol is None or pd.isna(domain_symbol):
            continue

        if domain_symbol in subdomain_with_precedence:
            in_subdomains.append(domain_symbol)

    if len(in_subdomains) == 0:
        print(
            f"No subdomains found: {structure_domain}. Setting to full name if structure_domain is length 1."
        )

        return return_first_full_domain_name(structure_domain)

    if len(in_subdomains) == 1:
        return in_subdomains[0]

    # make sure only 1 has precedence
    with_precedence = [d for d in in_subdomains if subdomain_with_precedence[d]]
    if len(with_precedence) == 1:
        return with_precedence[0]

    raise ValueError(f"Multiple subdomains found: {in_subdomains}")


def return_first_full_domain_name(structure_domain: list[dict]):
    if not structure_domain:
        return None

    if len(structure_domain) == 1:
        return structure_domain[0]["structure_domain"]

    print("WARNING: Multiple domains found.")
    return None

# %%
at_by_domain = data_all[
    [
        "individual_id",
        "hgvs_string",
        "structure_domains",
        "Atrial tachycardia",
        "Catecholaminergic polymorphic ventricular tachycardia 1",
    ]
].copy()

at_by_domain.drop_duplicates("individual_id", inplace=True)

at_by_domain = at_by_domain[at_by_domain[
                                "Catecholaminergic polymorphic ventricular tachycardia 1"] == 1]
at_by_domain = at_by_domain[at_by_domain["Atrial tachycardia"] == 1]
at_by_domain = at_by_domain[at_by_domain["structure_domains"].notna()]
at_by_domain["structure_domains"] = at_by_domain[
    "structure_domains"].str.replace("'", '"').str.replace("None", "null")


def foo(val):
    try:
        return json.loads(val)
    except Exception as e:
        print(val)
        raise e


at_by_domain["struct"] = at_by_domain["structure_domains"].apply(
    foo
)

domains = set(d.strip() for d in domains_df["domains"].values if pd.notna(d))

at_by_domain["domain"] = at_by_domain["struct"].apply(
    lambda x: find_domain(
        x, set(d.strip() for d in domains_df["domains"].values if pd.notna(d))
    )
)

subdomain_to_precedence = {
    d.strip(): p if pd.notna(p) else False
    for d, p in zip(
        domains_df["subdomains"].values,
        domains_df["subdomain_precedence"].values,
    )
    if pd.notna(d)
}

at_by_domain["subdomain"] = at_by_domain["struct"].apply(
    lambda x: find_subdomain(
        x,
        subdomain_to_precedence,
    )
)

at_by_domain.head()

# 
# for s in at_by_domain["struct"][:10]:
#     for v in s:
#         print(v)
#         
#     print("----")
# Out:
#      individual_id             hgvs_string  \
# 3                4  NM_001035.3:c.14174A>G
# 27              28  NM_001035.3:c.13933T>A
# 32              33  NM_001035.3:c.13933T>A
# 315            318   NM_001035.3:c.1259G>A
# 316            319   NM_001035.3:c.1259G>A
#
#                                      structure_domains  Atrial tachycardia  \
# 3    [{"structure_id": 23, "structure_domain": "Tra...                 1.0
# 27   [{"structure_id": 19, "structure_domain": "Act...                 1.0
# 32   [{"structure_id": 19, "structure_domain": "Act...                 1.0
# 315  [{"structure_id": 3, "structure_domain": "N-te...                 1.0
# 316  [{"structure_id": 3, "structure_domain": "N-te...                 1.0
#
#      Catecholaminergic polymorphic ventricular tachycardia 1  \
# 3                                                  1.0
# 27                                                 1.0
# 32                                                 1.0
# 315                                                1.0
# 316                                                1.0
#
#                                                 struct domain subdomain
# 3    [{'structure_id': 23, 'structure_domain': 'Tra...     TM      pVSD
# 27   [{'structure_id': 19, 'structure_domain': 'Act...     TM      pVSD
# 32   [{'structure_id': 19, 'structure_domain': 'Act...     TM      pVSD
# 315  [{'structure_id': 3, 'structure_domain': 'N-te...    NTD      NSol
# 316  [{'structure_id': 3, 'structure_domain': 'N-te...    NTD      NSol

# %%
at_by_domain["domain"].value_counts()
# Out:
# domain
# TM      9
# NTD     7
# CSol    3
# TaF     1
# JSol    1
# Name: count, dtype: int64

# %%
at_by_domain["domain"].value_counts().sum()
# Out:
# 21

# %%
at_by_domain["hgvs_string"].unique().shape
# Out:
# (13,)
