# %% [markdown]
# # Reviewer 2, Question 5
#
# The authors collected the data from 225 publications, and it might highlight hotspot of the RyR2 variants. However, as the RyR2 gene is large, only about 15% of the variants analyzed in the present study are found in patients at the reviewer’s institute.

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from pathlib import Path
from analysis.database import get_config

config = get_config()
data = pd.read_excel(
    Path.cwd().parent / "data" / f"individual_all_data-{config.version}.xlsx")
data.head()
# Out:
#    Unnamed: 0  individual_id     sex  publication_id  \
# 0           0              1     NaN               1
# 1           1              2  female               2
# 2           2              3    male               3
# 3           3              4  female               4
# 4           4              5    male               5
#
#                                                title     first_author  \
# 0  Familial Evaluation in Catecholaminergic Polym...   Van Der Werf C
# 1  Flecainide therapy reduces exercise-induced ve...  van der Werf, C
# 2  Structural abnormalities on cardiac magnetic r...        Gerber, D
# 3  Genetic Background of Catecholaminergic Polymo...      Kawamura, M
# 4  Gender differences in the inheritance mode of ...         Ohno, S.
#
#   reference                           doi  year publication_database  ...  \
# 0       NaN     10.1161/CIRCEP.112.970517  2012               PubMed  ...
# ...

# %%
# how many exons out of 105
len(data["exon_start"].dropna().unique())
# Out:
# 75
