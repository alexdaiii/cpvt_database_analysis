# %% [markdown]
# # Create Pivot Tables
#
# Create a pivot table of patients and conditions. Then combine all individuals and their variants into a single table for analysis.

# %%
import pandas as pd
import sqlalchemy as sa

# %%
# read db connection from .env file
from helpers.settings import get_settings

settings = get_settings()
# Out:
# Loading settings ...

# %%
engine = sa.create_engine(settings.postgresql_dsn.__str__())

# %%
df = pd.read_sql(
    """
SELECT i.individual_id, c.condition, ic.has_condition
FROM individual i
JOIN individual_condition ic
ON i.individual_id = ic.individual_id
JOIN condition c
ON ic.condition_id = c.condition_id
""",
    engine,
)
df.head()
# Out:
#    individual_id                                          condition  \
# 0              1  Catecholaminergic polymorphic ventricular tach...
# 1              1                        Heart Structure Abnormality
# 2              1     Baseline/resting electrocardiogram abnormality
# 3              1                Polymorphic ventricular tachycardia
# 4              1  Exercise/stress induced polymorphic ventricula...
#
#    has_condition
# 0           True
# 1          False
# 2          False
# 3           True
# 4           True

# %%
df2 = df.copy()
df2 = df2.pivot(index="individual_id", columns="condition", values="has_condition")
df2.reset_index(inplace=True)

df2.head()
# Out:
# condition  individual_id Adult-onset primary generalised epilepsy  \
# 0                      1                                      NaN
# 1                      2                                      NaN
# 2                      3                                      NaN
# 3                      4                                      NaN
# 4                      5                                      NaN
#
# condition Arrhythmia at rest Arrhythmogenic right ventricular cardiomyopathy  \
# 0                        NaN                                             NaN
# 1                        NaN                                             NaN
# 2                        NaN                                             NaN
# 3                      False                                             NaN
# 4                        NaN                                             NaN
#
# condition Arteriovenous malformation Ascending aortic aneurysm  \
# 0                                NaN                       NaN
# 1                                NaN                       NaN
# 2                                NaN                       NaN
# 3                                NaN                       NaN
# 4                                NaN                       NaN
#
# condition Atrial fibrillation Atrial flutter Atrial standstill  \
# 0                         NaN            NaN               NaN
# 1                         NaN            NaN               NaN
# 2                       False            NaN               NaN
# 3                       False            NaN               NaN
# 4                         NaN            NaN               NaN
#
# condition Atrial tachycardia  ... Sudden cardiac death  \
# 0                        NaN  ...                  NaN
# 1                        NaN  ...                  NaN
# 2                      False  ...                  NaN
# 3                       True  ...                  NaN
# 4                        NaN  ...                  NaN
#
# condition Sudden infant death syndrome Supraventricular tachycardia Syncope  \
# 0                                  NaN                          NaN     NaN
# 1                                  NaN                          NaN   False
# 2                                  NaN                          NaN    True
# 3                                  NaN                          NaN   False
# 4                                  NaN                          NaN    True
#
# condition Syncope exercise/stress induced Third-degree atrioventricular block  \
# 0                                     NaN                                 NaN
# 1                                     NaN                                 NaN
# 2                                    True                                 NaN
# 3                                     NaN                                 NaN
# 4                                     NaN                                 NaN
#
# condition Unspecified premature ventricular contractions  \
# 0                                                    NaN
# 1                                                  False
# 2                                                  False
# 3                                                  False
# 4                                                    NaN
#
# condition Ventricular fibrillation Ventricular tachycardia (unspecified)  \
# 0                              NaN                                   NaN
# 1                              NaN                                   NaN
# 2                              NaN                                   NaN
# 3                              NaN                                   NaN
# 4                              NaN                                   NaN
#
# condition Weight loss
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 92 columns]

# %%
# find the current working directory
import os
import IPython

notebook_path = IPython.get_ipython().getoutput('pwd')[0]

data_dir = os.path.join(notebook_path, '..', 'data')

if not os.path.exists(data_dir):
    print(f'Creating directory: {data_dir}')
    os.makedirs(data_dir)

# %%
# save to csv
df_file = os.path.join(data_dir, "individual_conditions.csv")
df2.to_csv(df_file, index=False)

# %% [markdown]
# # Combine purified data with rest of condition data

# %%
df_all_condition = pd.read_sql(
    """
SELECT i.individual_id, c.condition, ic.age_of_onset, ic.description, ic.onset_symptoms
FROM individual i
LEFT JOIN individual_condition ic
ON i.individual_id = ic.individual_id
LEFT JOIN condition c
ON ic.condition_id = c.condition_id
""",
    engine,
)
df_all_condition.head()
# Out:
#    individual_id                                          condition  \
# 0              1  Catecholaminergic polymorphic ventricular tach...
# 1              1                        Heart Structure Abnormality
# 2              1     Baseline/resting electrocardiogram abnormality
# 3              1                Polymorphic ventricular tachycardia
# 4              1  Exercise/stress induced polymorphic ventricula...
#
#    age_of_onset description onset_symptoms
# 0           NaN        None           None
# 1           NaN        None           None
# 2           NaN        None           None
# 3           NaN        None           None
# 4           NaN        None           None

# %%
df_all_condition.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13774 entries, 0 to 13773
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   individual_id   13774 non-null  int64
#  1   condition       13774 non-null  object
#  2   age_of_onset    411 non-null    float64
#  3   description     264 non-null    object
#  4   onset_symptoms  314 non-null    object
# dtypes: float64(1), int64(1), object(3)
# memory usage: 538.2+ KB

# %%
df_all_condition.groupby("individual_id")["description"].apply(
    lambda x: ", ".join(x.dropna())
).reset_index()
# Out:
#       individual_id                                        description
# 0                 1
# 1                 2
# 2                 3
# 3                 4
# 4                 5
# ...             ...                                                ...
# 1350           1351  Left ventricular hypertrabeculation at apex, B...
# 1351           1352
# 1352           1353                             Abnormal RV relaxation
# 1353           1354           Prominent left ventricular trabeculation
# 1354           1355  Noncompaction Cardiomyopathy (excessive apical...
#
# [1355 rows x 2 columns]

# %%
df3_pivot = df_all_condition.pivot(
    index="individual_id",
    columns="condition",
    values=["age_of_onset", "onset_symptoms"],
)
df3_pivot.reset_index(inplace=True)
# drop any columns that are all NaN
df3_pivot = df3_pivot.dropna(axis=1, how="all")
df3_pivot.columns = [
    "::".join(col).strip().strip(":") for col in df3_pivot.columns.values
]
# reset individual_id to a column
df3_pivot.set_index("individual_id", inplace=True)
# join the description column
df3_pivot = df3_pivot.join(
    df_all_condition.groupby("individual_id")["description"]
    .apply(lambda x: ", ".join(x.dropna()))
    .reset_index()
    .set_index("individual_id")
)
# rename the description column to "other conditions"
df3_pivot.rename(columns={"description": "other conditions"}, inplace=True)
df3_pivot.head()
# Out:
#               age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1  \
# individual_id
# 1                                                            NaN
# 2                                                            NaN
# 3                                                            NaN
# 4                                                            2.0
# 5                                                           10.0
#
#               onset_symptoms::Catecholaminergic polymorphic ventricular tachycardia 1  \
# individual_id
# 1                                                           None
# 2                                                           none
# 3                                                           None
# 4                                                           None
# 5                                                           None
#
#               other conditions
# individual_id
# 1
# 2
# 3
# 4
# 5

# %%
# save to csv
df3_pivot.to_csv(
    os.path.join(data_dir, "individual_conditions_descriptions.csv"), index=False
)

# %% [markdown]
# ## Family History Conditions

# %%
df4_pre = pd.read_sql(
    """
SELECT i.individual_id,
       c.condition,
       fmh.has_condition,
       kn.name AS relationship
FROM individual i
         LEFT JOIN family_history_record fhr
                   ON i.individual_id = fhr.individual_id
         LEFT JOIN condition c
                   ON fhr.condition_id = c.condition_id
         JOIN family_member_history fmh
                   ON fhr.family_history_record_id =
                      fmh.family_history_record_id
         JOIN kinship_name kn
                   ON fmh.kinship_name_id = kn.kinship_name_id
ORDER BY i.individual_id
""",
    engine,
)
df4_pre.head()
# Out:
#    individual_id             condition  has_condition relationship
# 0              1  Sudden cardiac death           True       Mother
# 1              1  Sudden cardiac death          False       Father
# 2             10  Sudden cardiac death           True       Mother
# 3             10  Sudden cardiac death          False       Father
# 4             11  Sudden cardiac death           True       Mother

# %%
df4_1_pivot = df4_pre.pivot(
    index="individual_id", columns=["condition", "relationship"], values="has_condition"
)
df4_1_pivot.reset_index(inplace=True)
df4_1_pivot.columns = [
    "::".join(col).strip().strip(":") for col in df4_1_pivot.columns.values
]
df4_1_pivot.set_index("individual_id", inplace=True)
df4_1_pivot.head()
# Out:
#                Sudden cardiac death::Mother  Sudden cardiac death::Father
# individual_id
# 1                                      True                         False
# 10                                     True                         False
# 11                                     True                         False
# 14                                     True                         False
# 15                                     True                         False

# %%
df4_2_pre = pd.read_sql(
    """
SELECT i.individual_id,
       c.condition,
       num_family_members
FROM individual i
         JOIN family_history_record fhr
                   ON i.individual_id = fhr.individual_id
         JOIN condition c
                   ON fhr.condition_id = c.condition_id
WHERE num_family_members IS NOT NULL
ORDER BY num_family_members DESC
""",
    engine,
)
df4_2_pre.head()
# Out:
#    individual_id             condition  num_family_members
# 0            991  Sudden cardiac death                  36
# 1            952  Sudden cardiac death                  36
# 2            954  Sudden cardiac death                  36
# 3            956  Sudden cardiac death                  36
# 4            958  Sudden cardiac death                  36

# %%
df4_2_pivot = df4_2_pre.pivot(
    index="individual_id", columns="condition", values="num_family_members"
).reset_index()
df4_2_pivot.columns = [
    f"{col}::num_family_members" if col != "individual_id" else col
    for col in df4_2_pivot.columns.values
]
df4_2_pivot.set_index("individual_id", inplace=True)
df4_2_pivot.head()
# Out:
#                Sudden cardiac death::num_family_members
# individual_id
# 4                                                     0
# 9                                                     0
# 13                                                    0
# 14                                                    0
# 15                                                    0

# %%
# combine the two dataframes - not all individuals will be in both
df4_pivot = df4_1_pivot.join(df4_2_pivot, how="outer")
df4_pivot.head()
# Out:
#               Sudden cardiac death::Mother Sudden cardiac death::Father  \
# individual_id
# 1                                     True                        False
# 4                                      NaN                          NaN
# 9                                      NaN                          NaN
# 10                                    True                        False
# 11                                    True                        False
#
#                Sudden cardiac death::num_family_members
# individual_id
# 1                                                   NaN
# 4                                                   0.0
# 9                                                   0.0
# 10                                                  NaN
# 11                                                  NaN

# %%
# save to csv
df4_pivot.to_csv(
    os.path.join(data_dir, "individual_family_conditions.csv"),
)

# %% [markdown]
# ## Treatments

# %%
df5 = pd.read_sql(
    """
SELECT i.individual_id,
       tr.treatment_taken,
       tr.effective,
       t.treatment_name
FROM individual i
         JOIN treatment_record tr
                   ON i.individual_id = tr.patient_id
         LEFT JOIN treatment t
                   ON tr.treatment_id = t.treatment_id
ORDER BY i.individual_id
""",
    engine,
)
df5.head()
# Out:
#    individual_id  treatment_taken effective  \
# 0              2             True     False
# 1              2            False      None
# 2              2             True      True
# 3              2            False      None
# 4              2            False      None
#
#                          treatment_name
# 0                          Beta blocker
# 1                             Verapamil
# 2                            Flecainide
# 3                             Enalapril
# 4  Left cardiac sympathetic denervation

# %%
df5_pivot = df5.pivot(
    index="individual_id",
    columns="treatment_name",
    values=["treatment_taken", "effective"],
)
df5_pivot.reset_index(inplace=True)
df5_pivot.columns = [
    "::".join(col).strip().strip(":") for col in df5_pivot.columns.values
]
df5_pivot.set_index("individual_id", inplace=True)
df5_pivot.head()
# Out:
#               treatment_taken::Beta blocker  \
# individual_id
# 2                                      True
# 4                                      True
# 6                                     False
# 7                                     False
# 8                                     False
#
#               treatment_taken::Catheter ablation treatment_taken::Enalapril  \
# individual_id
# 2                                          False                      False
# 4                                          False                      False
# 6                                            NaN                        NaN
# 7                                            NaN                        NaN
# 8                                          False                      False
#
#               treatment_taken::Flecainide  \
# individual_id
# 2                                    True
# 4                                   False
# 6                                     NaN
# 7                                     NaN
# 8                                   False
#
#               treatment_taken::Implantable cardioverter-defibrillator  \
# individual_id
# 2                                                          False
# 4                                                          False
# 6                                                            NaN
# 7                                                            NaN
# 8                                                           True
#
#               treatment_taken::Left cardiac sympathetic denervation  \
# individual_id
# 2                                                          False
# 4                                                          False
# 6                                                            NaN
# 7                                                            NaN
# 8                                                          False
#
#               treatment_taken::Verapamil effective::Beta blocker  \
# individual_id
# 2                                  False                   False
# 4                                  False                    None
# 6                                    NaN                    None
# 7                                    NaN                    None
# 8                                  False                    None
#
#               effective::Catheter ablation effective::Enalapril  \
# individual_id
# 2                                     None                 None
# 4                                     None                 None
# 6                                      NaN                  NaN
# 7                                      NaN                  NaN
# 8                                     None                 None
#
#               effective::Flecainide  \
# individual_id
# 2                              True
# 4                              None
# 6                               NaN
# 7                               NaN
# 8                              None
#
#               effective::Implantable cardioverter-defibrillator  \
# individual_id
# 2                                                          None
# 4                                                          None
# 6                                                           NaN
# 7                                                           NaN
# 8                                                          True
#
#               effective::Left cardiac sympathetic denervation  \
# individual_id
# 2                                                        None
# 4                                                        None
# 6                                                         NaN
# 7                                                         NaN
# 8                                                        None
#
#               effective::Verapamil
# individual_id
# 2                             None
# 4                             None
# 6                              NaN
# 7                              NaN
# 8                             None

# %%
# save to csv
df5_pivot.to_csv(
    os.path.join(data_dir, "individual_treatments.csv"),
)

# %% [markdown]
# # Combine all data

# %%
df_rest = pd.read_sql(
    """
SELECT i.individual_id,
       iis.value              AS sex,
       iv.variant_id,
       z.zygosity,
       vi.variant_inheritance AS inheritance,
       v.hgvs_string,
       sv.p_hgvs_string,
       itp.publication_id,
       p.title,
       p.first_author,
       p.pmid,
       p.reference,
       p.doi,
       p.year,
       i.extra_information
FROM individual i
         LEFT JOIN individual_sex iis
                   ON i.individual_sex_id = iis.individual_sex_id
         LEFT JOIN individual_variant iv
                   ON i.individual_id = iv.individual_id
         LEFT JOIN zygosity z
                   ON iv.zygosity_id = z.zygosity_id
         LEFT JOIN variant_inheritance vi
                   ON iv.variant_inheritance_id = vi.variant_inheritance_id
         LEFT JOIN variant v
                   ON iv.variant_id = v.variant_id
         LEFT JOIN individual_to_publication itp
                   ON i.individual_id = itp.individual_id
         LEFT JOIN publication p
                   ON itp.publication_id = p.publication_id
         LEFT JOIN sequence_variant sv
                   ON v.sequence_variant_id = sv.sequence_variant_id
ORDER BY i.individual_id;
""",
    engine,
)
df_rest.head()
# Out:
#    individual_id     sex  variant_id      zygosity  inheritance  \
# 0              1    None        8027  heterozygous    inherited
# 1              2  female        7854          None         None
# 2              3    male        7490          None         None
# 3              4  female        7491  heterozygous         None
# 4              5    male        7491          None  spontaneous
#
#                  hgvs_string  publication_id  \
# 0  NM_001035.3:c.13564-41A>G               1
# 1     NM_001035.3:c.14885A>G               2
# 2     NM_001035.3:c.14173T>A               3
# 3     NM_001035.3:c.14174A>G               4
# 4     NM_001035.3:c.14174A>G               5
#
#                                                title     first_author  \
# 0  Familial Evaluation in Catecholaminergic Polym...   Van Der Werf C
# 1  Flecainide therapy reduces exercise-induced ve...  van der Werf, C
# 2  Structural abnormalities on cardiac magnetic r...        Gerber, D
# 3  Genetic Background of Catecholaminergic Polymo...      Kawamura, M
# 4  Gender differences in the inheritance mode of ...         Ohno, S.
#
#          pmid                                          reference   doi  \
# 0  22787013.0  https://www.ncbi.nlm.nih.gov/pubmed?cmd=Retrie...  None
# 1  21616285.0       https://www.ncbi.nlm.nih.gov/pubmed/21616285  None
# 2  32553227.0  https://www.sciencedirect.com/science/article/...  None
# 3  23595086.0       https://www.ncbi.nlm.nih.gov/pubmed/23595086  None
# 4  26114861.0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  None
#
#      year                                  extra_information
# 0  2012.0  {'basic_science': False, 'maternity_paternity_...
# 1  2011.0                           {'basic_science': False}
# 2  2020.0  {'basic_science': False, 'maternity_paternity_...
# 3  2013.0                           {'basic_science': False}
# 4  2015.0  {'basic_science': False, 'maternity_paternity_...

# %%
df_all = (
    df_rest.set_index("individual_id")
    .join(df2)
    .join(df3_pivot)
    .join(df4_pivot)
    .join(df5_pivot)
)
df_all.drop(columns="individual_id", inplace=True)
df_all.head()
# Out:
#                   sex  variant_id      zygosity  inheritance  \
# individual_id
# 1                None        8027  heterozygous    inherited
# 2              female        7854          None         None
# 3                male        7490          None         None
# 4              female        7491  heterozygous         None
# 5                male        7491          None  spontaneous
#
#                              hgvs_string  publication_id  \
# individual_id
# 1              NM_001035.3:c.13564-41A>G               1
# 2                 NM_001035.3:c.14885A>G               2
# 3                 NM_001035.3:c.14173T>A               3
# 4                 NM_001035.3:c.14174A>G               4
# 5                 NM_001035.3:c.14174A>G               5
#
#                                                            title  \
# individual_id
# 1              Familial Evaluation in Catecholaminergic Polym...
# 2              Flecainide therapy reduces exercise-induced ve...
# 3              Structural abnormalities on cardiac magnetic r...
# 4              Genetic Background of Catecholaminergic Polymo...
# 5              Gender differences in the inheritance mode of ...
#
#                   first_author        pmid  \
# individual_id
# 1               Van Der Werf C  22787013.0
# 2              van der Werf, C  21616285.0
# 3                    Gerber, D  32553227.0
# 4                  Kawamura, M  23595086.0
# 5                     Ohno, S.  26114861.0
#
#                                                        reference  ...  \
# individual_id                                                     ...
# 1              https://www.ncbi.nlm.nih.gov/pubmed?cmd=Retrie...  ...
# 2                   https://www.ncbi.nlm.nih.gov/pubmed/21616285  ...
# 3              https://www.sciencedirect.com/science/article/...  ...
# 4                   https://www.ncbi.nlm.nih.gov/pubmed/23595086  ...
# 5              https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  ...
#
#               treatment_taken::Implantable cardioverter-defibrillator  \
# individual_id
# 1                                                            NaN
# 2                                                          False
# 3                                                            NaN
# 4                                                          False
# 5                                                            NaN
#
#                treatment_taken::Left cardiac sympathetic denervation  \
# individual_id
# 1                                                            NaN
# 2                                                          False
# 3                                                            NaN
# 4                                                          False
# 5                                                            NaN
#
#               treatment_taken::Verapamil  effective::Beta blocker  \
# individual_id
# 1                                    NaN                      NaN
# 2                                  False                    False
# 3                                    NaN                      NaN
# 4                                  False                     None
# 5                                    NaN                      NaN
#
#               effective::Catheter ablation effective::Enalapril  \
# individual_id
# 1                                      NaN                  NaN
# 2                                     None                 None
# 3                                      NaN                  NaN
# 4                                     None                 None
# 5                                      NaN                  NaN
#
#               effective::Flecainide  \
# individual_id
# 1                               NaN
# 2                              True
# 3                               NaN
# 4                              None
# 5                               NaN
#
#               effective::Implantable cardioverter-defibrillator  \
# individual_id
# 1                                                           NaN
# 2                                                          None
# 3                                                           NaN
# 4                                                          None
# 5                                                           NaN
#
#               effective::Left cardiac sympathetic denervation  \
# individual_id
# 1                                                         NaN
# 2                                                        None
# 3                                                         NaN
# 4                                                        None
# 5                                                         NaN
#
#               effective::Verapamil
# individual_id
# 1                              NaN
# 2                             None
# 3                              NaN
# 4                             None
# 5                              NaN
#
# [5 rows x 125 columns]

# %%
import datetime

# drop the individual_id column
date = datetime.datetime.now().strftime("%Y-%m-%d")

date
# Out:
# '2024-07-05'

# %%
# save to csv
df_all.to_excel(
    os.path.join(data_dir, f"individual_all_data-{date}.xlsx"),
)

# %%
# export all publications
df_publications = pd.read_sql(
    """
SELECT p.publication_id, p.title, p.first_author, p.pmid, p.reference, p.doi, p.year
FROM publication p
ORDER BY p.title
""",
    engine,
)
df_publications.head()

# %%
df_publications.to_csv(os.path.join(data_dir, f"publications-{date}.csv"), index=False)
