# %%
import os
import duckdb

clinvar_duckdb_loc = (
    "~/dev/2023/cpvt-database-cleanup/data/clinvar/clinvar.duckdb"
)

if not os.path.exists(os.path.expanduser(clinvar_duckdb_loc)):
    raise FileNotFoundError(
        f"File not found: {clinvar_duckdb_loc}"
    )

conn = duckdb.connect(clinvar_duckdb_loc)

# %%
conn.execute(
    """
SELECT *
FROM clinvar
LIMIT 5
"""
).fetchdf()
# Out:
#    #AlleleID                       Type  \
# 0      15041                      Indel
# 1      15041                      Indel
# 2      15042                   Deletion
# 3      15042                   Deletion
# 4      15043  single nucleotide variant
#
#                                                 Name  GeneID GeneSymbol  \
# 0  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 1  NM_014855.3(AP5Z1):c.80_83delinsTGCTGTAAACTGTA...    9907      AP5Z1
# 2     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 3     NM_014855.3(AP5Z1):c.1413_1426del (p.Leu473fs)    9907      AP5Z1
# 4       NM_014630.3(ZNF592):c.3136G>A (p.Gly1046Arg)    9640     ZNF592
#
#       HGNC_ID    ClinicalSignificance  ClinSigSimple LastEvaluated  \
# 0  HGNC:22197              Pathogenic              0             -
# 1  HGNC:22197              Pathogenic              0             -
# 2  HGNC:22197              Pathogenic              0  Jun 29, 2010
# 3  HGNC:22197              Pathogenic              0  Jun 29, 2010
# 4  HGNC:28986  Uncertain significance              0  Jun 29, 2015
#
#    RS# (dbSNP)  ... VariationID PositionVCF ReferenceAlleleVCF  \
# 0    397704705  ...           2     4820844               GGAT
# 1    397704705  ...           2     4781213               GGAT
# 2    397704709  ...           3     4827360    GCTGCTGGACCTGCC
# 3    397704709  ...           3     4787729    GCTGCTGGACCTGCC
# 4    150829393  ...           4    85342440                  G
#
#        AlternateAlleleVCF SomaticClinicalImpact  \
# 0  TGCTGTAAACTGTAACTGTAAA                     -
# 1  TGCTGTAAACTGTAACTGTAAA                     -
# 2                       G                     -
# 3                       G                     -
# 4                       A                     -
#
#   SomaticClinicalImpactLastEvaluated ReviewStatusClinicalImpact Oncogenicity  \
# 0                                  -                          -            -
# 1                                  -                          -            -
# 2                                  -                          -            -
# 3                                  -                          -            -
# 4                                  -                          -            -
#
#   OncogenicityLastEvaluated  ReviewStatusOncogenicity
# 0                         -                         -
# 1                         -                         -
# 2                         -                         -
# 3                         -                         -
# 4                         -                         -
#
# [5 rows x 40 columns]

# %%
# Get the table names
conn.execute(
    """
SELECT COUNT(*)
FROM clinvar
WHERE Assembly = 'GRCh38'
"""
).fetchall()
# Out:
# [(2921042,)]

# %%
# As of 07/2024 there are 2,921,042 variants in the GRCh38 assembly

# %%
conn.execute(
    """
SELECT 
    GeneSymbol,
    COUNT(*) AS num_variants
FROM clinvar
WHERE Assembly = 'GRCh38'
GROUP BY GeneSymbol
ORDER BY num_variants DESC
LIMIT 25
"""
).fetchdf()
# Out:
#    GeneSymbol  num_variants
# 0         TTN         31076
# 1       BRCA2         18561
# 2         ATM         16427
# 3         APC         14607
# 4       BRCA1         14241
# 5         NF1         14046
# 6         NEB         10870
# 7        TSC2         10630
# 8        MSH6          9128
# 9        POLE          9122
# 10       RYR1          9116
# 11      USH2A          8254
# 12        DMD          8212
# 13       RYR2          7906
# 14       FBN1          7628
# 15       MSH2          7168
# 16     DICER1          6386
# 17      ALMS1          6258
# 18     ADGRV1          6213
# 19      SYNE1          6188
# 20      PALB2          5770
# 21      DNAH5          5683
# 22     DNAH11          5660
# 23       PLEC          5621
# 24     VPS13B          5556

# %%
conn.execute("""
SELECT *
FROM clinvar
WHERE Assembly = 'GRCh38'
AND GeneSymbol = 'RYR2'
LIMIT 5
""").df()
# Out:
#    #AlleleID                       Type  \
# 0      27993  single nucleotide variant
# 1      27994  single nucleotide variant
# 2      27995  single nucleotide variant
# 3      27996  single nucleotide variant
# 4      27997  single nucleotide variant
#
#                                           Name  GeneID GeneSymbol     HGNC_ID  \
# 0   NM_001035.3(RYR2):c.6737C>T (p.Ser2246Leu)    6262       RYR2  HGNC:10484
# 1   NM_001035.3(RYR2):c.7422G>C (p.Arg2474Ser)    6262       RYR2  HGNC:10484
# 2  NM_001035.3(RYR2):c.12312C>G (p.Asn4104Lys)    6262       RYR2  HGNC:10484
# 3  NM_001035.3(RYR2):c.13489C>T (p.Arg4497Cys)    6262       RYR2  HGNC:10484
# 4   NM_001035.3(RYR2):c.7157A>T (p.Asn2386Ile)    6262       RYR2  HGNC:10484
#
#   ClinicalSignificance  ClinSigSimple LastEvaluated  RS# (dbSNP)  ...  \
# 0           Pathogenic              0  Jun 17, 2023    121918597  ...
# 1           Pathogenic              0  Jan 16, 2001    121918598  ...
# 2           Pathogenic              0  Jan 16, 2001    121918599  ...
# 3           Pathogenic              0  Oct 11, 2023    121918600  ...
# 4           Pathogenic              0  Nov 07, 2022    121918601  ...
#
#   VariationID PositionVCF ReferenceAlleleVCF AlternateAlleleVCF  \
# 0       12954   237634937                  C                  T
# 1       12955   237648523                  G                  C
# 2       12956   237784024                  C                  G
# 3       12957   237791441                  C                  T
# 4       12958   237640938                  A                  T
#
#   SomaticClinicalImpact SomaticClinicalImpactLastEvaluated  \
# 0                     -                                  -
# 1                     -                                  -
# 2                     -                                  -
# 3                     -                                  -
# 4                     -                                  -
#
#   ReviewStatusClinicalImpact Oncogenicity OncogenicityLastEvaluated  \
# 0                          -            -                         -
# 1                          -            -                         -
# 2                          -            -                         -
# 3                          -            -                         -
# 4                          -            -                         -
#
#    ReviewStatusOncogenicity
# 0                         -
# 1                         -
# 2                         -
# 3                         -
# 4                         -
#
# [5 rows x 40 columns]

# %%
phenotypes = conn.execute("""
SELECT PhenotypeList
FROM clinvar
WHERE Assembly = 'GRCh38'
AND GeneSymbol = 'RYR2'
""").df()

phenotypes.head()
# Out:
#                                        PhenotypeList
# 0  Catecholaminergic polymorphic ventricular tach...
# 1  Catecholaminergic polymorphic ventricular tach...
# 2  Catecholaminergic polymorphic ventricular tach...
# 3  Catecholaminergic polymorphic ventricular tach...
# 4  Catecholaminergic polymorphic ventricular tach...

# %%
# split the phenotypes by "|" and count the number of unique phenotypes
# also split phenotypes by ";" and count the number of unique phenotypes
phenotypes2 = phenotypes.PhenotypeList.str.split("[|;]", expand=True)
phenotypes2 = phenotypes2.stack().reset_index(drop=True)

phenotypes2.value_counts()
# Out:
# Catecholaminergic polymorphic ventricular tachycardia 1                                          5131
# Cardiomyopathy                                                                                   2497
# Catecholaminergic polymorphic ventricular tachycardia                                            2366
# not provided                                                                                     1675
# Cardiovascular phenotype                                                                         1673
# not specified                                                                                     793
# Arrhythmogenic right ventricular dysplasia 2                                                      540
# Ventricular arrhythmias due to cardiac ryanodine receptor calcium release deficiency syndrome     229
# RYR2-related disorder                                                                              81
# Arrhythmogenic right ventricular cardiomyopathy                                                    73
# Cardiac arrhythmia                                                                                 30
# Long QT syndrome                                                                                   21
# Hypertrophic cardiomyopathy                                                                        20
# Primary familial hypertrophic cardiomyopathy                                                       18
# Primary dilated cardiomyopathy                                                                     11
# Conduction disorder of the heart                                                                    7
# Wolff-Parkinson-White pattern                                                                       7
# Polymorphic ventricular tachycardia                                                                 4
# Arrhythmogenic right ventricular dysplasia 1                                                        3
# Cardiac arrest                                                                                      2
# Ventricular fibrillation, paroxysmal familial, type 1                                               2
# Sudden unexplained death                                                                            2
# Sudden cardiac death                                                                                2
# Childhood-onset schizophrenia                                                                       2
# Left ventricular noncompaction                                                                      2
# Primary familial dilated cardiomyopathy                                                             2
# Death in infancy                                                                                    1
# Left ventricular noncompaction cardiomyopathy                                                       1
# Ventricular fibrillation                                                                            1
# Dilated cardiomyopathy with left ventricular noncompaction                                          1
# Diastolic dysfunction                                                                               1
# Congestive heart failure                                                                            1
# Ventricular tachycardia                                                                             1
# Heart disease                                                                                       1
# Arrhythmogenic right ventricular dysplasia 9                                                        1
# Hypertrophic cardiomyopathy 4                                                                       1
# 6 conditions                                                                                        1
# Catecholaminergic polymorphic ventricular tachycardia 2                                             1
# Sudden cardiac arrest                                                                               1
# Brugada syndrome                                                                                    1
# Sudden death                                                                                        1
# Syncope                                                                                             1
# Right ventricular cardiomyopathy                                                                    1
# Premature coronary artery atherosclerosis                                                           1
# Long QT syndrome 1                                                                                  1
# Paroxysmal familial ventricular fibrillation                                                        1
# EBV-positive nodal T- and NK-cell lymphoma                                                          1
# Name: count, dtype: int64

# %%
# do for phenotypeIDs
phenotype_ids = conn.execute("""
SELECT PhenotypeIDS
FROM clinvar
WHERE Assembly = 'GRCh38'
AND GeneSymbol = 'RYR2'
""").df()

phenotype_ids.PhenotypeIDS.str.split("[|;]", expand=True).stack().value_counts()
# Out:
# MONDO:MONDO:0011484,MedGen:C1631597,OMIM:604772,Orphanet:3286                                                                                                                                                                                                                                                                                                                              5131
# Human Phenotype Ontology:HP:0001638,MONDO:MONDO:0004994,MedGen:C0878544,Orphanet:167848                                                                                                                                                                                                                                                                                                    2497
# MONDO:MONDO:0017990,MedGen:C5574922,OMIM:PS604772,Orphanet:3286                                                                                                                                                                                                                                                                                                                            2366
# MedGen:CN230736                                                                                                                                                                                                                                                                                                                                                                            1673
# MedGen:C3661900                                                                                                                                                                                                                                                                                                                                                                            1510
# MedGen:CN169374                                                                                                                                                                                                                                                                                                                                                                             793
# MedGen:C1832931                                                                                                                                                                                                                                                                                                                                                                             540
# MONDO:MONDO:0020745,MedGen:C5542154,OMIM:115000                                                                                                                                                                                                                                                                                                                                             229
# MedGen:CN517202                                                                                                                                                                                                                                                                                                                                                                             165
#                                                                                                                                                                                                                                                                                                                                                                                              77
# MONDO:MONDO:0016587,MedGen:C0349788,Orphanet:247                                                                                                                                                                                                                                                                                                                                             73
# EFO:EFO_0004269,Human Phenotype Ontology:HP:0001656,Human Phenotype Ontology:HP:0001661,Human Phenotype Ontology:HP:0001665,Human Phenotype Ontology:HP:0001666,Human Phenotype Ontology:HP:0001687,Human Phenotype Ontology:HP:0001721,Human Phenotype Ontology:HP:0004351,Human Phenotype Ontology:HP:0005158,Human Phenotype Ontology:HP:0011675,MONDO:MONDO:0007263,MedGen:C0003811      30
# MONDO:MONDO:0002442,MeSH:D008133,MedGen:C0023976                                                                                                                                                                                                                                                                                                                                             21
# Human Phenotype Ontology:HP:0001639,MONDO:MONDO:0005045,MeSH:D002312,MedGen:C0007194,Orphanet:217569                                                                                                                                                                                                                                                                                         20
# MONDO:MONDO:0024573,MeSH:D024741,MedGen:C0949658,OMIM:PS192600,Orphanet:155                                                                                                                                                                                                                                                                                                                  18
# EFO:EFO_0000407,Human Phenotype Ontology:HP:0001644,Human Phenotype Ontology:HP:0001725,Human Phenotype Ontology:HP:0005159,Human Phenotype Ontology:HP:0200130,MONDO:MONDO:0005021,MeSH:D002311,MedGen:C0007193,Orphanet:217604                                                                                                                                                             11
# MONDO:MONDO:0100042,MedGen:C0264886,OMIM:115080,Orphanet:871                                                                                                                                                                                                                                                                                                                                  7
# Human Phenotype Ontology:HP:0001716,MONDO:MONDO:0008685,MedGen:C0043202,OMIM:194200,Orphanet:907                                                                                                                                                                                                                                                                                              7
# -                                                                                                                                                                                                                                                                                                                                                                                             5
# Human Phenotype Ontology:HP:0031677,MONDO:MONDO:0020575,MedGen:C0344432                                                                                                                                                                                                                                                                                                                       4
# MONDO:MONDO:0007152,MedGen:C1862511,OMIM:107970,Orphanet:3403                                                                                                                                                                                                                                                                                                                                 3
# MONDO:MONDO:0011376,MedGen:C2751898,OMIM:603829,Orphanet:228140                                                                                                                                                                                                                                                                                                                               2
# Human Phenotype Ontology:HP:0001695,MONDO:MONDO:0000745,MedGen:C0018790                                                                                                                                                                                                                                                                                                                       2
# MedGen:C0520806                                                                                                                                                                                                                                                                                                                                                                               2
# MONDO:MONDO:0957430,MedGen:C0036346                                                                                                                                                                                                                                                                                                                                                           2
# Human Phenotype Ontology:HP:0030682,MONDO:MONDO:0018901,MedGen:C1960469,OMIM:PS604169,Orphanet:54260                                                                                                                                                                                                                                                                                          2
# MONDO:MONDO:0016333,MedGen:C0340427,OMIM:PS115200,Orphanet:217607                                                                                                                                                                                                                                                                                                                             2
# EFO:EFO_0004278,Human Phenotype Ontology:HP:0001645,Human Phenotype Ontology:HP:0005161,MeSH:D016757,MedGen:C0085298                                                                                                                                                                                                                                                                          2
# Human Phenotype Ontology:HP:0001522,Human Phenotype Ontology:HP:0003816,Human Phenotype Ontology:HP:0003817,Human Phenotype Ontology:HP:0003818,Human Phenotype Ontology:HP:0003823,Human Phenotype Ontology:HP:0003827,MedGen:C1858430                                                                                                                                                       1
# Human Phenotype Ontology:HP:0011664,MedGen:C4021133                                                                                                                                                                                                                                                                                                                                           1
# MedGen:C1853863                                                                                                                                                                                                                                                                                                                                                                               1
# MedGen:C0520863                                                                                                                                                                                                                                                                                                                                                                               1
# Human Phenotype Ontology:HP:0001635,Human Phenotype Ontology:HP:0006686,MONDO:MONDO:0005009,MedGen:C0018802                                                                                                                                                                                                                                                                                   1
# EFO:EFO_0005306,Human Phenotype Ontology:HP:0004756,MONDO:MONDO:0005477,MedGen:C0042514                                                                                                                                                                                                                                                                                                       1
# EFO:EFO_0004287,Human Phenotype Ontology:HP:0001663,Human Phenotype Ontology:HP:0005166,MONDO:MONDO:0000190,MedGen:C0042510                                                                                                                                                                                                                                                                   1
# MONDO:MONDO:0005267,MedGen:C0018799                                                                                                                                                                                                                                                                                                                                                           1
# MONDO:MONDO:0007268,MedGen:C1861862,OMIM:115197                                                                                                                                                                                                                                                                                                                                               1
# 6 conditions                                                                                                                                                                                                                                                                                                                                                                                  1
# MONDO:MONDO:0012762,MedGen:C2677794,OMIM:611938,Orphanet:3286                                                                                                                                                                                                                                                                                                                                 1
# MONDO:MONDO:0012180,MedGen:C1836906,OMIM:609040                                                                                                                                                                                                                                                                                                                                               1
# MONDO:MONDO:0100511,MedGen:C1720824                                                                                                                                                                                                                                                                                                                                                           1
# MONDO:MONDO:0015263,MedGen:C1142166,OMIM:PS601144,Orphanet:130                                                                                                                                                                                                                                                                                                                                1
# Human Phenotype Ontology:HP:0001279,MedGen:C0039070                                                                                                                                                                                                                                                                                                                                           1
# Human Phenotype Ontology:HP:0001699,MedGen:C0011071                                                                                                                                                                                                                                                                                                                                           1
# Human Phenotype Ontology:HP:0011663,MedGen:C2063326                                                                                                                                                                                                                                                                                                                                           1
# Human Phenotype Ontology:HP:0005181,MedGen:C1867743                                                                                                                                                                                                                                                                                                                                           1
# MONDO:MONDO:0100316,MedGen:C4551647,OMIM:192500,Orphanet:101016,Orphanet:768                                                                                                                                                                                                                                                                                                                  1
# MONDO:MONDO:0100234,MedGen:C0340493,Orphanet:228140                                                                                                                                                                                                                                                                                                                                           1
# Name: count, dtype: int64

# %%
# get number of GRCH38 RYR2 variants
conn.execute("""
SELECT COUNT(*)
FROM clinvar
WHERE Assembly = 'GRCh38'
AND GeneSymbol = 'RYR2'
""").fetchdf()
# Out:
#    count_star()
# 0          7906
