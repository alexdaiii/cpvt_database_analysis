# %% [markdown]
# ### Create tables for Supplemental Tables
#
# Cleans up and makes it easier to read

# %%
import pandas as pd
import os
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt
import yaml

from analysis.database import get_config

config = get_config()

# create dir for figures
figures_dir = Path(
    os.path.join("..", "figures", config.version_for_dir, "analysis_12"))

if not os.path.exists(figures_dir):
    print(f"Creating directory: {figures_dir}")
    os.makedirs(figures_dir)

# %%
df = pd.read_excel(
    f"../data/individual_all_data-{config.version}.xlsx",
    index_col=0,
)
df.head()
# Out:
#    individual_id     sex  publication_id  \
# 0              1     NaN               1
# 1              2  female               2
# 2              3    male               3
# 3              4  female               4
# 4              5    male               5
#
#                                                title     first_author  \
# 0  Familial Evaluation in Catecholaminergic Polym...   Van Der Werf C
# 1  Flecainide therapy reduces exercise-induced ve...  van der Werf, C
# 2  Structural abnormalities on cardiac magnetic r...        Gerber, D
# 3  Genetic Background of Catecholaminergic Polymo...      Kawamura, M
# 4  Gender differences in the inheritance mode of ...         Ohno, S.
#
#   reference                           doi  year publication_database  \
# 0       NaN     10.1161/CIRCEP.112.970517  2012               PubMed
# 1       NaN    10.1016/j.jacc.2011.01.026  2011               PubMed
# 2       NaN   10.1016/j.jacep.2020.03.006  2020               PubMed
# 3       NaN      10.1253/circj.cj-12-1460  2013               PubMed
# 4       NaN  10.1371/journal.pone.0131517  2015               PubMed
#
#                                resource_uri  ...  \
# 0  https://pubmed.ncbi.nlm.nih.gov/22787013  ...
# 1  https://pubmed.ncbi.nlm.nih.gov/21616285  ...
# 2  https://pubmed.ncbi.nlm.nih.gov/32553227  ...
# 3  https://pubmed.ncbi.nlm.nih.gov/23595086  ...
# 4  https://pubmed.ncbi.nlm.nih.gov/26114861  ...
#
#   treatment_taken::Implantable cardioverter-defibrillator  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#   treatment_taken::Left cardiac sympathetic denervation  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#    treatment_taken::Verapamil effective::Beta blocker  \
# 0                         NaN                     NaN
# 1                         0.0                     0.0
# 2                         NaN                     NaN
# 3                         0.0                     NaN
# 4                         NaN                     NaN
#
#    effective::Catheter ablation effective::Enalapril  effective::Flecainide  \
# 0                           NaN                  NaN                    NaN
# 1                           NaN                  NaN                    1.0
# 2                           NaN                  NaN                    NaN
# 3                           NaN                  NaN                    NaN
# 4                           NaN                  NaN                    NaN
#
#    effective::Implantable cardioverter-defibrillator  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   effective::Left cardiac sympathetic denervation effective::Verapamil
# 0                                             NaN                  NaN
# 1                                             NaN                  NaN
# 2                                             NaN                  NaN
# 3                                             NaN                  NaN
# 4                                             NaN                  NaN
#
# [5 rows x 158 columns]

# %%
df_pubs = df[
    ["publication_id",
     "title",
     "first_author",
     "reference",
     "doi",
     "year",
     "publication_database",
     "resource_uri",
     "resource_id",
     "doi_uri",
     "publication_type",
     "rob_publication_type"
     ]
]
# only unique publications
df_pubs = df_pubs.drop_duplicates(subset="publication_id")

print(f"Number of unique publications: {df_pubs.shape[0]}")

df_pubs.head()
# Out:
# Number of unique publications: 221
#    publication_id                                              title  \
# 0               1  Familial Evaluation in Catecholaminergic Polym...
# 1               2  Flecainide therapy reduces exercise-induced ve...
# 2               3  Structural abnormalities on cardiac magnetic r...
# 3               4  Genetic Background of Catecholaminergic Polymo...
# 4               5  Gender differences in the inheritance mode of ...
#
#       first_author reference                           doi  year  \
# 0   Van Der Werf C       NaN     10.1161/CIRCEP.112.970517  2012
# 1  van der Werf, C       NaN    10.1016/j.jacc.2011.01.026  2011
# 2        Gerber, D       NaN   10.1016/j.jacep.2020.03.006  2020
# 3      Kawamura, M       NaN      10.1253/circj.cj-12-1460  2013
# 4         Ohno, S.       NaN  10.1371/journal.pone.0131517  2015
#
#   publication_database                              resource_uri resource_id  \
# 0               PubMed  https://pubmed.ncbi.nlm.nih.gov/22787013    22787013
# 1               PubMed  https://pubmed.ncbi.nlm.nih.gov/21616285    21616285
# 2               PubMed  https://pubmed.ncbi.nlm.nih.gov/32553227    32553227
# 3               PubMed  https://pubmed.ncbi.nlm.nih.gov/23595086    23595086
# 4               PubMed  https://pubmed.ncbi.nlm.nih.gov/26114861    26114861
#
#                                         doi_uri publication_type  \
# 0     https://doi.org/10.1161/CIRCEP.112.970517          Article
# 1    https://doi.org/10.1016/j.jacc.2011.01.026          Article
# 2   https://doi.org/10.1016/j.jacep.2020.03.006  Research Letter
# 3      https://doi.org/10.1253/circj.cj-12-1460          Article
# 4  https://doi.org/10.1371/journal.pone.0131517          Article
#
#                    rob_publication_type
# 0  Cohort or Cross-Sectional Like Study
# 1  Cohort or Cross-Sectional Like Study
# 2  Cohort or Cross-Sectional Like Study
# 3                           Case Series
# 4                           Case Series

# %% [markdown]
# ### Check if doi resolve
#
# Limit to 10 resolutions/second (note doi has a limit of 1000 resolutions/5 min

# %%
import asyncio
import aiohttp

sem = asyncio.Semaphore(10)


async def fetch_doi(sess, doi):
    """
    Returns the status code
    """
    url = f"https://doi.org/{doi}"
    async with sem:
        async with sess.get(url) as res:
            return doi, res.status


# jupyter allows for "top level" await
async with aiohttp.ClientSession() as session:
    tasks = []

    for doi in df_pubs["doi"].dropna().unique():
        tasks.append(fetch_doi(session, doi))

    results = await asyncio.gather(*tasks)

results_df = pd.DataFrame(results, columns=["doi", "status"])
results_df.head()
# Out:
#                             doi  status
# 0     10.1161/CIRCEP.112.970517     403
# 1    10.1016/j.jacc.2011.01.026     200
# 2   10.1016/j.jacep.2020.03.006     200
# 3      10.1253/circj.cj-12-1460     200
# 4  10.1371/journal.pone.0131517     200

# %%
# save results to csv
results_df.to_csv(figures_dir / f"doi_status{config.version}.csv", index=False)

# %%
# merge results with df_pubs
df_pubs_checked = df_pubs.merge(results_df, on="doi", how="left")
# for 404 status codes, replace doi with None
df_pubs_checked["doi_uri"] = df_pubs_checked["doi_uri"].where(
    df_pubs_checked["status"] != 404, None)
df_pubs_checked.head()
# Out:
#    publication_id                                              title  \
# 0               1  Familial Evaluation in Catecholaminergic Polym...
# 1               2  Flecainide therapy reduces exercise-induced ve...
# 2               3  Structural abnormalities on cardiac magnetic r...
# 3               4  Genetic Background of Catecholaminergic Polymo...
# 4               5  Gender differences in the inheritance mode of ...
#
#       first_author reference                           doi  year  \
# 0   Van Der Werf C       NaN     10.1161/CIRCEP.112.970517  2012
# 1  van der Werf, C       NaN    10.1016/j.jacc.2011.01.026  2011
# 2        Gerber, D       NaN   10.1016/j.jacep.2020.03.006  2020
# 3      Kawamura, M       NaN      10.1253/circj.cj-12-1460  2013
# 4         Ohno, S.       NaN  10.1371/journal.pone.0131517  2015
#
#   publication_database                              resource_uri resource_id  \
# 0               PubMed  https://pubmed.ncbi.nlm.nih.gov/22787013    22787013
# 1               PubMed  https://pubmed.ncbi.nlm.nih.gov/21616285    21616285
# 2               PubMed  https://pubmed.ncbi.nlm.nih.gov/32553227    32553227
# 3               PubMed  https://pubmed.ncbi.nlm.nih.gov/23595086    23595086
# 4               PubMed  https://pubmed.ncbi.nlm.nih.gov/26114861    26114861
#
#                                         doi_uri publication_type  \
# 0     https://doi.org/10.1161/CIRCEP.112.970517          Article
# 1    https://doi.org/10.1016/j.jacc.2011.01.026          Article
# 2   https://doi.org/10.1016/j.jacep.2020.03.006  Research Letter
# 3      https://doi.org/10.1253/circj.cj-12-1460          Article
# 4  https://doi.org/10.1371/journal.pone.0131517          Article
#
#                    rob_publication_type  status
# 0  Cohort or Cross-Sectional Like Study   403.0
# 1  Cohort or Cross-Sectional Like Study   200.0
# 2  Cohort or Cross-Sectional Like Study   200.0
# 3                           Case Series   200.0
# 4                           Case Series   200.0

# %%
# for the uris only keep doi, if not then resource_uri
df_pubs_checked["link"] = df_pubs_checked["doi_uri"].fillna(
    df_pubs_checked["resource_uri"])
df_pubs_checked.head()
# Out:
#    publication_id                                              title  \
# 0               1  Familial Evaluation in Catecholaminergic Polym...
# 1               2  Flecainide therapy reduces exercise-induced ve...
# 2               3  Structural abnormalities on cardiac magnetic r...
# 3               4  Genetic Background of Catecholaminergic Polymo...
# 4               5  Gender differences in the inheritance mode of ...
#
#       first_author reference                           doi  year  \
# 0   Van Der Werf C       NaN     10.1161/CIRCEP.112.970517  2012
# 1  van der Werf, C       NaN    10.1016/j.jacc.2011.01.026  2011
# 2        Gerber, D       NaN   10.1016/j.jacep.2020.03.006  2020
# 3      Kawamura, M       NaN      10.1253/circj.cj-12-1460  2013
# 4         Ohno, S.       NaN  10.1371/journal.pone.0131517  2015
#
#   publication_database                              resource_uri resource_id  \
# 0               PubMed  https://pubmed.ncbi.nlm.nih.gov/22787013    22787013
# 1               PubMed  https://pubmed.ncbi.nlm.nih.gov/21616285    21616285
# 2               PubMed  https://pubmed.ncbi.nlm.nih.gov/32553227    32553227
# 3               PubMed  https://pubmed.ncbi.nlm.nih.gov/23595086    23595086
# 4               PubMed  https://pubmed.ncbi.nlm.nih.gov/26114861    26114861
#
#                                         doi_uri publication_type  \
# 0     https://doi.org/10.1161/CIRCEP.112.970517          Article
# 1    https://doi.org/10.1016/j.jacc.2011.01.026          Article
# 2   https://doi.org/10.1016/j.jacep.2020.03.006  Research Letter
# 3      https://doi.org/10.1253/circj.cj-12-1460          Article
# 4  https://doi.org/10.1371/journal.pone.0131517          Article
#
#                    rob_publication_type  status  \
# 0  Cohort or Cross-Sectional Like Study   403.0
# 1  Cohort or Cross-Sectional Like Study   200.0
# 2  Cohort or Cross-Sectional Like Study   200.0
# 3                           Case Series   200.0
# 4                           Case Series   200.0
#
#                                            link
# 0     https://doi.org/10.1161/CIRCEP.112.970517
# 1    https://doi.org/10.1016/j.jacc.2011.01.026
# 2   https://doi.org/10.1016/j.jacep.2020.03.006
# 3      https://doi.org/10.1253/circj.cj-12-1460
# 4  https://doi.org/10.1371/journal.pone.0131517

# %%
# check for missing values
# THESE NEED TO BE MANUALLY FILLED IN!!!
df_pubs_checked[df_pubs_checked["link"].isna()]
# Out:
#      publication_id                                              title  \
# 36               82  Ryanodine receptor 2 mutation: Not only catech...
# 129             548  Novel ryanodine receptor mutation associated w...
# 153             742  Occult structural disease in patients with cat...
#
#      first_author                                          reference  \
# 36         She, Y  Yingfang She, Yide Li, Hang Yu, Liemin Zhou. R...
# 129  Alvarado, F.                                                NaN
# 153    Gerber, DA                                                NaN
#
#                                   doi  year publication_database resource_uri  \
# 36                                NaN  2020                  NaN          NaN
# 129  10.1161/circ.128.suppl_22.A16239  2018                  NaN          NaN
# 153    10.1161/circ.134.suppl_1.20771  2016                  NaN          NaN
#
#     resource_id doi_uri              publication_type  \
# 36          NaN     NaN                       Article
# 129         NaN    None  Conference / Poster Abstract
# 153         NaN    None  Conference / Poster Abstract
#
#                      rob_publication_type  status link
# 36                            Case Report     NaN  NaN
# 129                           Case Report   404.0  NaN
# 153  Cohort or Cross-Sectional Like Study   404.0  NaN

# %%
df_pubs_cleaned = df_pubs_checked[[
    "publication_id",
    "title",
    "first_author",
    "year",
    "link",
    "publication_database",
    "publication_type",
    "rob_publication_type"
]].copy()
# rename rob_publication_type to study_type
df_pubs_cleaned.rename(columns={"rob_publication_type": "study_design_type"},
                       inplace=True)
df_pubs_cleaned.head()
# Out:
#    publication_id                                              title  \
# 0               1  Familial Evaluation in Catecholaminergic Polym...
# 1               2  Flecainide therapy reduces exercise-induced ve...
# 2               3  Structural abnormalities on cardiac magnetic r...
# 3               4  Genetic Background of Catecholaminergic Polymo...
# 4               5  Gender differences in the inheritance mode of ...
#
#       first_author  year                                          link  \
# 0   Van Der Werf C  2012     https://doi.org/10.1161/CIRCEP.112.970517
# 1  van der Werf, C  2011    https://doi.org/10.1016/j.jacc.2011.01.026
# 2        Gerber, D  2020   https://doi.org/10.1016/j.jacep.2020.03.006
# 3      Kawamura, M  2013      https://doi.org/10.1253/circj.cj-12-1460
# 4         Ohno, S.  2015  https://doi.org/10.1371/journal.pone.0131517
#
#   publication_database publication_type                     study_design_type
# 0               PubMed          Article  Cohort or Cross-Sectional Like Study
# 1               PubMed          Article  Cohort or Cross-Sectional Like Study
# 2               PubMed  Research Letter  Cohort or Cross-Sectional Like Study
# 3               PubMed          Article                           Case Series
# 4               PubMed          Article                           Case Series

# %%
# save unique publications to excel
df_pubs_cleaned.to_excel(
    figures_dir / f"publications_unique{config.version}.xlsx",
    index=False)

# %% [markdown]
# ### Summary of the studies included

# %%
# load in the "fixed" data
df_filled = pd.read_excel(
    figures_dir / f"publications_unique{config.version}-filled.xlsx",
)
df_filled.head()
# Out:
#    publication_id                                              title  \
# 0               1  Familial Evaluation in Catecholaminergic Polym...
# 1               2  Flecainide therapy reduces exercise-induced ve...
# 2               3  Structural abnormalities on cardiac magnetic r...
# 3               4  Genetic Background of Catecholaminergic Polymo...
# 4               5  Gender differences in the inheritance mode of ...
#
#       first_author  year                                          link  \
# 0   Van Der Werf C  2012     https://doi.org/10.1161/CIRCEP.112.970517
# 1  van der Werf, C  2011    https://doi.org/10.1016/j.jacc.2011.01.026
# 2        Gerber, D  2020   https://doi.org/10.1016/j.jacep.2020.03.006
# 3      Kawamura, M  2013      https://doi.org/10.1253/circj.cj-12-1460
# 4         Ohno, S.  2015  https://doi.org/10.1371/journal.pone.0131517
#
#   publication_database publication_type                     study_design_type
# 0               PubMed          Article  Cohort or Cross-Sectional Like Study
# 1               PubMed          Article  Cohort or Cross-Sectional Like Study
# 2               PubMed  Research Letter  Cohort or Cross-Sectional Like Study
# 3               PubMed          Article                           Case Series
# 4               PubMed          Article                           Case Series

# %%
study_types = df_filled["study_design_type"].value_counts()
study_types
# Out:
# study_design_type
# Case Series                             84
# Case Report                             77
# Cohort or Cross-Sectional Like Study    33
# Basic Science                           11
# Case Control Study                       8
# Diagnostic Accuracy Study                4
# Systematic Review                        2
# Gene Association Study                   2
# Name: count, dtype: int64

# %%
db_queried = df_filled["publication_database"].value_counts()
db_queried
# Out:
# publication_database
# PubMed    177
# Embase     25
# Name: count, dtype: int64

# %%
article_types = df_filled["publication_type"].value_counts()
article_types
# Out:
# publication_type
# Article                         164
# Conference / Poster Abstract     37
# Research Letter                  13
# Brief Communication               4
# Review                            2
# Textbook                          1
# Name: count, dtype: int64

# %%
# export these to excel
with pd.ExcelWriter(
        figures_dir / "publication_summary.xlsx",
        engine="openpyxl",
        mode="w",
) as writer:
    study_types.to_excel(writer, sheet_name="study_types")
    db_queried.to_excel(writer, sheet_name="db_queried")
    article_types.to_excel(writer, sheet_name="article_types")

# %% [markdown]
# ## Risk of Bias Tables

# %%
rob_tables_info = pd.read_excel(
    "data_commit/rob_analysis/rob_table_contents.xlsx"
)
rob_tables_info
# Out:
#                            file supplemental_table  \
# 0                           NaN           Table S2
# 1         rob_case_control.xlsx           Table S3
# 2          rob_case_report.xlsx           Table S4
# 3          rob_case_series.xlsx           Table S5
# 4               rob_cohort.xlsx           Table S6
# 5  rob_diagnostic_accuracy.xlsx           Table S7
# 6                   others.xlsx           Table S8
#
#                                          description
# 0              All publications used in the database
# 1  Risk of Bias Analysis for Case Control Studies...
# 2  Risk of Bias Analysis for Case Reports using t...
# 3  Risk of Bias Analysis for Case Series  using t...
# 4  Risk of Bias Analysis for Cohort or Cross-Sect...
# 5  Risk of Bias Analysis for Diagnostic Accuracy ...
# 6  Basic Science, Reviews, Clinical Trials Public...

# %%
columns_to_keep_rob = [
    "publication_id",
    "title",
    "link"
]

with pd.ExcelWriter(
        figures_dir / f"Supplementary_Tables_S2-S9-{config.version}.xlsx",
        engine="openpyxl",
        mode="w",
) as writer:
    # add a sheet in the beginning "Table of Contents"
    table_of_contents = rob_tables_info[[
        "supplemental_table",
        "description",
    ]].copy()

    table_of_contents.columns = ["Table", "Description"]

    # add a row that says "Supplementary Data" as the first row
    table_of_contents = pd.concat([
        pd.DataFrame([["Supplementary Data", ""]],
                     columns=["Table", "Description"]),
        table_of_contents,
    ])

    table_of_contents.to_excel(
        writer,
        sheet_name="Table of Contents",
        index=False,
    )

    for _, row in rob_tables_info.iterrows():
        if row["supplemental_table"] == "Table S2":
            df_filled.to_excel(
                writer,
                sheet_name=row["supplemental_table"],
                index=False,
            )
            continue

        df_rob = pd.read_excel(
            f"data_commit/rob_analysis/{row["file"]}"
        )

        # make sure all publication_ids are in df_filled
        if set(df_rob["publication_id"]) - set(df_filled["publication_id"]):
            print(
                f"Missing publication_ids in df_filled for {row['supplemental_table']}")
            continue

        #join with df_filled for the "link"
        df_rob = df_rob.merge(
            df_filled[[
                "publication_id",
                "link",
            ]],
            on="publication_id",
            how="left",
        )

        col_keep = columns_to_keep_rob + [
            # any column that starts with a number
            col for col in df_rob.columns if col[0].isdigit()
        ]

        df_rob = df_rob[col_keep]

        # if its table S8, add the publication_type and study_design_type
        if row["supplemental_table"] == "Table S8":
            df_rob = df_rob.merge(
                df_filled[[
                    "publication_id",
                    "publication_type",
                    "study_design_type"
                ]],
                on="publication_id",
                how="left",
            )

        print(f"Creating {row['supplemental_table']}")
        display(df_rob.head())

        df_rob.to_excel(
            writer,
            sheet_name=row["supplemental_table"],
            index=False,
        )
# Out:
# Creating Table S3
#    publication_id                                              title  \
# 0              59  Mutations of the Cardiac Ryanodine Receptor (R...
# 1              80  Molecular genetics of exercise-induced polymor...
# 2             109  Cardiac genetic disposition in sudden infant d...
# 3             116  Utility of post-mortem genetic testing in case...
# 4             712  Genetic analysis of hyperemesis gravidarum rev...
#
#                                          link  \
# 0    https://doi.org/10.1161/01.CIR.103.4.485
# 1     https://doi.org/10.1038/sj.ejhg.5201061
# 2  https://doi.org/10.1016/j.jacc.2018.01.030
# 3  https://doi.org/10.1016/j.jacc.2017.02.046
# 4   https://doi.org/10.1016/j.mce.2016.09.017
#
#   1. Was the research question or objective in this paper clearly stated and appropriate?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   2. Was the study population clearly specified and defined?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   3. Did the authors include a sample size justification?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                 NO
# 4                                                 NO
#
#   4. Were controls selected or recruited from the same or similar population that gave rise to the cases (including the same timeframe)?  \
# 0                                                YES
# 1                                                YES
# 2                                                 NO
# 3                                                 NO
# 4                                                YES
#
#   5. Were the definitions, inclusion and exclusion criteria, algorithms or processes used to identify or select cases and controls valid, reliable, and implemented consistently across all study participants?  \
# 0                                                 CD
# 1                                                 CD
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   6. Were the cases clearly defined and differentiated from controls?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#    7. If less than 100 percent of eligible cases and/or controls were selected for the study, were the cases and/or controls randomly selected from those eligible?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   8. Was there use of concurrent controls?  \
# 0                                       NO
# 1                                       NO
# 2                                       NO
# 3                                       NO
# 4                                       NO
#
#   9. Were the investigators able to confirm that the exposure/risk occurred prior to the development of the condition or event that defined a participant as a case?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   10. Were the measures of exposure/risk clearly defined, valid, reliable, and implemented consistently (including the same time period) across all study participants?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   11. Were the assessors of exposure/risk blinded to the case or control status of participants?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                 NO
# 4                                                 NM
#
#   12. Were key potential confounding variables measured and adjusted statistically in the analyses? If matching was used, did the investigators account for matching during study analysis?
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                YES
# 4                                                 NM
# Creating Table S4
#    publication_id                                              title  \
# 0               9  A de novo ryanodine receptor 2 gene variant in...
# 1              48  Successful treatment of catecholaminergic poly...
# 2              70  A novel mutation in the cardiac ryanodine rece...
# 3              82  Ryanodine receptor 2 mutation: Not only catech...
# 4              90  Catecholaminergic Polymorphic Ventricular Tach...
#
#                                                 link  \
# 0         https://doi.org/10.1007/s00414-019-02160-8
# 1            https://doi.org/10.1093/europace/euq517
# 2       https://doi.org/10.1016/j.ijcard.2010.10.062
# 3  https://www.neurology-asia.org/articles/neuroa...
# 4          https://doi.org/10.4070/kcj.2012.42.2.129
#
#   1. Were patient’s demographic characteristics clearly described?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   2. Was the patient’s history clearly described and presented as a timeline?  \
# 0                                                 NO
# 1                                                YES
# 2                                                 NO
# 3                                                 NO
# 4                                                 NO
#
#   3. Was the current clinical condition of the patient on presentation clearly described?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   4. Were diagnostic tests or assessment methods and the results clearly described?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   5. Was the intervention(s) or treatment procedure(s) clearly described?  \
# 0                                                NaN
# 1                                                YES
# 2                                                NaN
# 3                                                YES
# 4                                                YES
#
#   6. Was the post-intervention clinical condition clearly described?   \
# 0                                                NaN
# 1                                                YES
# 2                                                NaN
# 3                                                YES
# 4                                                YES
#
#   7. Were adverse events (harms) or unanticipated events identified and described?  \
# 0                                                NaN
# 1                                                YES
# 2                                                NaN
# 3                                                 NO
# 4                                                YES
#
#   8. Does the case report provide takeaway lessons?
# 0                                               YES
# 1                                               YES
# 2                                               YES
# 3                                               YES
# 4                                               YES
# Creating Table S5
#    publication_id                                              title  \
# 0               4  Genetic Background of Catecholaminergic Polymo...
# 1               5  Gender differences in the inheritance mode of ...
# 2               8  Refractory tachyarrhythmias caused by ryanodin...
# 3              16  Prevalence and significance of rare RYR2 varia...
# 4              24  Familial dilated cardiomyopathy associated wit...
#
#                                            link  \
# 0      https://doi.org/10.1253/circj.cj-12-1460
# 1  https://doi.org/10.1371/journal.pone.0131517
# 2   https://www.embase.com/records?id=L71893770
# 3   https://doi.org/10.1016/j.hrthm.2014.07.020
# 4         https://doi.org/10.5603/CJ.a2020.0099
#
#   1. Was the study question or objective clearly stated?   \
# 0                                                YES
# 1                                                YES
# 2                                                 NO
# 3                                                YES
# 4                                                YES
#
#   2. Was the study population clearly and fully described, including a case definition?  \
# 0                                               YES
# 1                                               YES
# 2                                                 NO
# 3                                                YES
# 4                                               YES
#
#   3. Were the cases consecutive? 4. Were the subjects comparable?  \
# 0                            YES                              YES
# 1                             NO                              YES
# 2                             NO                              YES
# 3                             CD                              YES
# 4                             NO                              YES
#
#   5. Was the intervention clearly described?  \
# 0                                        YES
# 1                                         NO
# 2                                         NO
# 3                                        YES
# 4                                        YES
#
#   6. Were the outcome measures clearly defined, valid, reliable, and implemented consistently across all study participants?  \
# 0                                                YES
# 1                                                 CD
# 2                                                 NO
# 3                                                YES
# 4                                                YES
#
#   7. Was the length of follow-up adequate?  \
# 0                                      YES
# 1                                      YES
# 2                                       CD
# 3                                      YES
# 4                                      YES
#
#   8. Were the statistical methods well-described?  \
# 0                                             YES
# 1                                             YES
# 2                                              NO
# 3                                             YES
# 4                                              NM
#
#   9. Were the results well-described?
# 0                                 YES
# 1                                 YES
# 2                                  NO
# 3                                 YES
# 4                                 YES
# Creating Table S6
#    publication_id                                              title  \
# 0               1  Familial Evaluation in Catecholaminergic Polym...
# 1               2  Flecainide therapy reduces exercise-induced ve...
# 2               3  Structural abnormalities on cardiac magnetic r...
# 3               6  Bradycardia is a specific phenotype of catecho...
# 4              11  Linking the heart and the brain: Neurodevelopm...
#
#                                                link  \
# 0         https://doi.org/10.1161/CIRCEP.112.970517
# 1        https://doi.org/10.1016/j.jacc.2011.01.026
# 2       https://doi.org/10.1016/j.jacep.2020.03.006
# 3  https://doi.org/10.2169/internalmedicine.9843-17
# 4       https://doi.org/10.1016/j.hrthm.2018.08.025
#
#   1. Was the research question or objective in this paper clearly stated?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   2. Was the study population clearly specified and defined?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   3. Was the participation rate of eligible persons at least 50%?  \
# 0                                                YES
# 1                                                 CD
# 2                                                 CD
# 3                                                 CD
# 4                                                YES
#
#   4. Were all the subjects selected or recruited from the same or similar populations (including the same time period)? Were inclusion and exclusion criteria for being in the study prespecified and applied uniformly to all participants?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   5. Was a sample size justification, power description, or variance and effect estimates provided?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                 NO
# 4                                                 NO
#
#   6. For the analyses in this paper, were the exposure(s) of interest measured prior to the outcome(s) being measured?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   7. Was the timeframe sufficient so that one could reasonably expect to see an association between exposure and outcome if it existed?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   8. For exposures that can vary in amount or level, did the study examine different levels of the exposure as related to the outcome (e.g., categories of exposure, or exposure measured as continuous variable)?  \
# 0                                                NaN
# 1                                                 NO
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   9. Were the exposure measures (independent variables) clearly defined, valid, reliable, and implemented consistently across all study participants?  \
# 0                                                YES
# 1                                                YES
# 2                                                 NO
# 3                                                YES
# 4                                                YES
#
#   10. Was the exposure(s) assessed more than once over time?  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#   11. Were the outcome measures (dependent variables) clearly defined, valid, reliable, and implemented consistently across all study participants?  \
# 0                                                YES
# 1                                                YES
# 2                                                 NO
# 3                                                YES
# 4                                                YES
#
#   12. Were the outcome assessors blinded to the exposure status of participants?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                 NO
# 4                                                 NO
#
#   13. Was loss to follow-up after baseline 20% or less?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
# 4                                                YES
#
#   14. Were key potential confounding variables measured and adjusted statistically for their impact on the relationship between exposure(s) and outcome(s)?
# 0                                                 NO
# 1                                                 NM
# 2                                                 NO
# 3                                                 NO
# 4                                                YES
# Creating Table S7
#    publication_id                                              title  \
# 0              13  Assessment and validation of a phenotype-enhan...
# 1              36  Differential diagnosis between catecholaminerg...
# 2             190  Next Generation Sequencing Challenges in the A...
# 3            1163  Intravenous Epinephrine Infusion Test in Diagn...
#
#                                                link  \
# 0        https://doi.org/10.1161/CIRCGEN.119.002510
# 1          https://doi.org/10.1253/circj.CJ-17-1032
# 2            https://doi.org/10.1002/elps.201400148
# 3  https://doi.org/10.1111/j.1540-8167.2011.02188.x
#
#   1.\tWas a consecutive or random sample of patients enrolled?  \
# 0                                                 NO
# 1                                                 NO
# 2                                                 NO
# 3                                                 NO
#
#   2.\tWas a case control design avoided?  \
# 0                                    YES
# 1                                    YES
# 2                                    YES
# 3                                    YES
#
#   3.\tDid the study avoid inappropriate exclusions?  \
# 0                                               YES
# 1                                               YES
# 2                                               YES
# 3                                               YES
#
#   4.\tWere the index test results interpreted without knowledge of the results of the reference standard?  \
# 0                                                 CD
# 1                                                 CD
# 2                                                 NO
# 3                                                 CD
#
#   5.\tIf a threshold was used, was it pre-specified?  \
# 0                                                YES
# 1                                                 NO
# 2                                                NaN
# 3                                                NaN
#
#   6.\tIs the reference standard likely to correctly classify the target condition?  \
# 0                                                YES
# 1                                                 NO
# 2                                                YES
# 3                                                YES
#
#   7.\tWere the reference standard results interpreted without knowledge of the results of the index test?  \
# 0                                                YES
# 1                                                 CD
# 2                                                 CD
# 3                                                 CD
#
#   8.\tWas there an appropriate interval between index test and reference standard?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
#
#   9.\tDid all patients receive the same reference standard?  \
# 0                                                YES
# 1                                                YES
# 2                                                YES
# 3                                                YES
#
#   10.\tWere all patients included in the analysis?
# 0                                              YES
# 1                                              YES
# 2                                               NO
# 3                                              YES
# Creating Table S8
#    publication_id                                              title  \
# 0              40  Denaturing HPLC-based approach for detecting R...
# 1             147  Flecainide prevents catecholaminergic polymorp...
# 2             148  Catecholaminergic polymorphic ventricular tach...
# 3             157  Dantrolene rescues arrhythmogenic RYR2 defect ...
# 4             192  Exome Analyses of Long QT Syndrome Reveal Cand...
#
#                                            link     publication_type  \
# 0  https://doi.org/10.1373/clinchem.2003.030734              Article
# 1               https://doi.org/10.1038/nm.1942  Brief Communication
# 2  https://doi.org/10.1136/heartjnl-2012-302033               Review
# 3        https://doi.org/10.1002/emmm.201100194              Article
# 4  https://doi.org/10.1371/journal.pone.0130329              Article
#
#         study_design_type
# 0           Basic Science
# 1           Basic Science
# 2       Systematic Review
# 3           Basic Science
# 4  Gene Association Study

# %% [markdown]
# ## Table S9
#
# This table contains all the data used for the analysis

# %%
df_for_table_s9 = df.join(
    df_filled.set_index("publication_id")[
        [
            "link",
            "study_design_type",
        ]
    ],
    on="publication_id",

)

df_for_table_s9.head()
# Out:
#    individual_id     sex  publication_id  \
# 0              1     NaN               1
# 1              2  female               2
# 2              3    male               3
# 3              4  female               4
# 4              5    male               5
#
#                                                title     first_author  \
# 0  Familial Evaluation in Catecholaminergic Polym...   Van Der Werf C
# 1  Flecainide therapy reduces exercise-induced ve...  van der Werf, C
# 2  Structural abnormalities on cardiac magnetic r...        Gerber, D
# 3  Genetic Background of Catecholaminergic Polymo...      Kawamura, M
# 4  Gender differences in the inheritance mode of ...         Ohno, S.
#
#   reference                           doi  year publication_database  \
# 0       NaN     10.1161/CIRCEP.112.970517  2012               PubMed
# 1       NaN    10.1016/j.jacc.2011.01.026  2011               PubMed
# 2       NaN   10.1016/j.jacep.2020.03.006  2020               PubMed
# 3       NaN      10.1253/circj.cj-12-1460  2013               PubMed
# 4       NaN  10.1371/journal.pone.0131517  2015               PubMed
#
#                                resource_uri  ... treatment_taken::Verapamil  \
# 0  https://pubmed.ncbi.nlm.nih.gov/22787013  ...                        NaN
# 1  https://pubmed.ncbi.nlm.nih.gov/21616285  ...                        0.0
# 2  https://pubmed.ncbi.nlm.nih.gov/32553227  ...                        NaN
# 3  https://pubmed.ncbi.nlm.nih.gov/23595086  ...                        0.0
# 4  https://pubmed.ncbi.nlm.nih.gov/26114861  ...                        NaN
#
#   effective::Beta blocker  effective::Catheter ablation effective::Enalapril  \
# 0                     NaN                           NaN                  NaN
# 1                     0.0                           NaN                  NaN
# 2                     NaN                           NaN                  NaN
# 3                     NaN                           NaN                  NaN
# 4                     NaN                           NaN                  NaN
#
#    effective::Flecainide effective::Implantable cardioverter-defibrillator  \
# 0                    NaN                                               NaN
# 1                    1.0                                               NaN
# 2                    NaN                                               NaN
# 3                    NaN                                               NaN
# 4                    NaN                                               NaN
#
#    effective::Left cardiac sympathetic denervation  effective::Verapamil  \
# 0                                              NaN                   NaN
# 1                                              NaN                   NaN
# 2                                              NaN                   NaN
# 3                                              NaN                   NaN
# 4                                              NaN                   NaN
#
#                                            link  \
# 0     https://doi.org/10.1161/CIRCEP.112.970517
# 1    https://doi.org/10.1016/j.jacc.2011.01.026
# 2   https://doi.org/10.1016/j.jacep.2020.03.006
# 3      https://doi.org/10.1253/circj.cj-12-1460
# 4  https://doi.org/10.1371/journal.pone.0131517
#
#                       study_design_type
# 0  Cohort or Cross-Sectional Like Study
# 1  Cohort or Cross-Sectional Like Study
# 2  Cohort or Cross-Sectional Like Study
# 3                           Case Series
# 4                           Case Series
#
# [5 rows x 160 columns]

# %%
# get the list of columns starting from "Adult-onset primary generalised epilepsy" to "Weight loss" excluding any columns that say "Other"

excluded_cols = {
    "primary_diagnosis",
    # was broken up into individual columns
    "condition_descriptions",
    # becomes "onset_symptoms::Catecholaminergic polymorphic ventricular tachycardia 1
    "condition_onset_symptoms",
}

disease_cols_s9 = [
    col for i, col in enumerate(df_for_table_s9.columns)
    if (
            df_for_table_s9.columns.get_loc(
                "Adult-onset primary generalised epilepsy") <= i <= df_for_table_s9.columns.get_loc(
        "effective::Verapamil")
            and col not in excluded_cols
            and "Other" not in col
    )
]

disease_cols_s9
# Out:
# ['Adult-onset primary generalised epilepsy',
#  'Arrhythmia at rest',
#  'Arrhythmogenic right ventricular cardiomyopathy',
#  'Arteriovenous malformation',
#  'Ascending aortic aneurysm',
#  'Atrial fibrillation',
#  'Atrial flutter',
#  'Atrial standstill',
#  'Atrial tachycardia',
#  'Attention deficit hyperactivity disorder',
#  'Baseline/resting electrocardiogram abnormality',
#  'Bradycardia',
#  'Bronchial asthma',
#  'Brugada syndrome',
#  'Catecholaminergic polymorphic ventricular tachycardia 1',
#  'Catecholaminergic polymorphic ventricular tachycardia 1 asymptomatic carrier',
#  'Chest pain, unspecified',
#  'Chronotropic incompetence',
#  'Colon cancer',
#  'Congenital atrioventricular block',
#  'Developmental delay',
#  'Diabetes mellitus',
#  'Dilated cardiomyopathy',
#  'Dizziness',
#  'Dyspnea',
#  'Effort-induced polymorphic ventricular arrhythmia',
#  'Electrical storm',
#  'Exercise/stress induced Long QT syndrome',
#  'Exercise/stress induced atrial fibrillation',
#  'Exercise/stress induced atrial tachycardia',
#  'Exercise/stress induced monomorphic premature ventricular contractions',
#  'Exercise/stress induced monomorphic ventricular tachycardia',
#  'Exercise/stress induced polymorphic premature ventricular contractions',
#  'Exercise/stress induced polymorphic ventricular tachycardia',
#  'Exercise/stress induced premature atrial contraction',
#  'Exercise/stress induced seizure',
#  'Exercise/stress induced sudden cardiac arrest',
#  'Exercise/stress induced unspecified premature ventricular contractions',
#  'Fetal tachycardia',
#  'Glucose intolerance',
#  'Heart Structure Abnormality',
#  'Heart failure',
#  'Hemoptysis',
#  'Hereditary spastic paraplegia',
#  'Histological abnormalities',
#  'Hyperglycemia',
#  'Hypertelorism',
#  'Hypertension',
#  'Hypertrophic cardiomyopathy',
#  'Hypoplastic left heart syndrome',
#  'Hypothyroidism',
#  'Hypoxic-ischemic encephalopathy',
#  'Intellectual disability',
#  'Left ventricular non-compaction',
#  'Long QT syndrome',
#  'Mesenteric lymphadenitis',
#  'Monomorphic premature ventricular contractions',
#  'Monomorphic ventricular tachycardia',
#  'Neurofibromatosis',
#  'Noncompaction cardiomyopathy',
#  'Palpitations',
#  'Paroxysmal nocturnal dyspnea',
#  'Polymorphic premature ventricular contractions',
#  'Polymorphic ventricular tachycardia',
#  'Postural orthostatic tachycardia syndrome',
#  'Precordial catch syndrome',
#  'Premature atrial contraction',
#  'Rectal cancer',
#  'Scoliosis',
#  'Seizure',
#  'Short-coupled variant of torsade de pointes',
#  'Sinus node dysfunction',
#  'Sinus tachycardia',
#  'Status lymphaticus',
#  'Substance use disorder',
#  'Sudden cardiac arrest',
#  'Sudden cardiac death',
#  'Sudden infant death syndrome',
#  'Supraventricular tachycardia',
#  'Syncope',
#  'Syncope exercise/stress induced',
#  'Third-degree atrioventricular block',
#  'Unspecified premature ventricular contractions',
#  'Ventricular fibrillation',
#  'Ventricular tachycardia (unspecified)',
#  'Weight loss',
#  'age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1',
#  'onset_symptoms::Catecholaminergic polymorphic ventricular tachycardia 1',
#  'age_of_presentation::Catecholaminergic polymorphic ventricular tachycardia 1',
#  'Sudden cardiac death::Mother',
#  'Sudden cardiac death::Father',
#  'Sudden cardiac death::num_family_members',
#  'treatment_taken::Beta blocker',
#  'treatment_taken::Catheter ablation',
#  'treatment_taken::Enalapril',
#  'treatment_taken::Flecainide',
#  'treatment_taken::Implantable cardioverter-defibrillator',
#  'treatment_taken::Left cardiac sympathetic denervation',
#  'treatment_taken::Verapamil',
#  'effective::Beta blocker',
#  'effective::Catheter ablation',
#  'effective::Enalapril',
#  'effective::Flecainide',
#  'effective::Implantable cardioverter-defibrillator',
#  'effective::Left cardiac sympathetic denervation',
#  'effective::Verapamil']

# %%
# where are condition_descriptions or condition_onset_symptoms not null
df_for_table_s9[df_for_table_s9[
    "condition_onset_symptoms"].notnull()
][["onset_symptoms::Catecholaminergic polymorphic ventricular tachycardia 1",
   "condition_onset_symptoms"]]
# Out:
#      onset_symptoms::Catecholaminergic polymorphic ventricular tachycardia 1  \
# 1                                                  none
# 27                Ritalin-induced irregular heart beats
# 32                                              syncope
# 33                                                 none
# 47                                              syncope
# ...                                                 ...
# 1329                                            syncope
# 1330                                            syncope
# 1331                              Syncope w/ convulsion
# 1338                                       SCD Drowning
# 1339                                       SCD Drowning
#
#                    condition_onset_symptoms
# 1                                      none
# 27    Ritalin-induced irregular heart beats
# 32                                  syncope
# 33                                     none
# 47                                  syncope
# ...                                     ...
# 1329                                syncope
# 1330                                syncope
# 1331                  Syncope w/ convulsion
# 1338                           SCD Drowning
# 1339                           SCD Drowning
#
# [312 rows x 2 columns]

# %%
df_columns = [
                 "individual_id",
                 "sex",
                 "publication_id",
                 "title",
                 "first_author",
                 "year",
                 "link",
                 "publication_type",
                 "study_design_type",
                 "variant_id",
                 "clinvar_uri",
                 "hgvs_string",
                 "c_hgvs_string",
                 "p_hgvs_string",
                 "p_hgvs_aa1",
                 "cdna_change_type",
                 "protein_change_type",
                 "zygosity",
                 "inheritance",
                 "exon_start",
                 "exon_end",
                 "structure_domains",
                 "domain",
                 "subdomain",
             ] + disease_cols_s9

df_for_table_s9_filtered = df_for_table_s9[df_columns]
df_for_table_s9_filtered.head()
# Out:
#    individual_id     sex  publication_id  \
# 0              1     NaN               1
# 1              2  female               2
# 2              3    male               3
# 3              4  female               4
# 4              5    male               5
#
#                                                title     first_author  year  \
# 0  Familial Evaluation in Catecholaminergic Polym...   Van Der Werf C  2012
# 1  Flecainide therapy reduces exercise-induced ve...  van der Werf, C  2011
# 2  Structural abnormalities on cardiac magnetic r...        Gerber, D  2020
# 3  Genetic Background of Catecholaminergic Polymo...      Kawamura, M  2013
# 4  Gender differences in the inheritance mode of ...         Ohno, S.  2015
#
#                                            link publication_type  \
# 0     https://doi.org/10.1161/CIRCEP.112.970517          Article
# 1    https://doi.org/10.1016/j.jacc.2011.01.026          Article
# 2   https://doi.org/10.1016/j.jacep.2020.03.006  Research Letter
# 3      https://doi.org/10.1253/circj.cj-12-1460          Article
# 4  https://doi.org/10.1371/journal.pone.0131517          Article
#
#                       study_design_type  variant_id  ...  \
# 0  Cohort or Cross-Sectional Like Study         609  ...
# 1  Cohort or Cross-Sectional Like Study         599  ...
# 2  Cohort or Cross-Sectional Like Study         681  ...
# 3                           Case Series        3698  ...
# 4                           Case Series        3698  ...
#
#   treatment_taken::Implantable cardioverter-defibrillator  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#   treatment_taken::Left cardiac sympathetic denervation  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#   treatment_taken::Verapamil effective::Beta blocker  \
# 0                        NaN                     NaN
# 1                        0.0                     0.0
# 2                        NaN                     NaN
# 3                        0.0                     NaN
# 4                        NaN                     NaN
#
#   effective::Catheter ablation effective::Enalapril effective::Flecainide  \
# 0                          NaN                  NaN                   NaN
# 1                          NaN                  NaN                   1.0
# 2                          NaN                  NaN                   NaN
# 3                          NaN                  NaN                   NaN
# 4                          NaN                  NaN                   NaN
#
#   effective::Implantable cardioverter-defibrillator  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
#
#   effective::Left cardiac sympathetic denervation  effective::Verapamil
# 0                                             NaN                   NaN
# 1                                             NaN                   NaN
# 2                                             NaN                   NaN
# 3                                             NaN                   NaN
# 4                                             NaN                   NaN
#
# [5 rows x 130 columns]

# %%
df_for_table_s9_filtered.to_excel(
    figures_dir / f"Supplementary_Table_S9-{config.version}.xlsx",
    index=False,
)
