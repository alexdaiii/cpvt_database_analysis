# %% [markdown]
# # Is the Age of Onset different between the incidence of CPVT symptoms?

# %%
import pandas as pd
import numpy as np
from pathlib import Path
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from analysis.database import get_config, FigureParams, set_figure_size

config = get_config()

# %% [markdown]
# Authors mention that a severe phenotype of patients is associate with younger onset of the age. Symptoms include both syncope and sudden cardiac arrest.
# Are there any differences in the age of onset between syncope and sudden cardiac arrest?

# %%
data = pd.read_excel(
    Path.cwd().parent / "data" / f"individual_all_data-{config.version}.xlsx")

data.head()
# Out:
#    Unnamed: 0  individual_id     sex  publication_id  \
# 0           0              1     NaN               1
# 1           1              2  female               2
# 2           2              3    male               3
# 3           3              4  female               4
# 4           4              5    male               5
#
#                                                title     first_author  \
# 0  Familial Evaluation in Catecholaminergic Polym...   Van Der Werf C
# 1  Flecainide therapy reduces exercise-induced ve...  van der Werf, C
# 2  Structural abnormalities on cardiac magnetic r...        Gerber, D
# 3  Genetic Background of Catecholaminergic Polymo...      Kawamura, M
# 4  Gender differences in the inheritance mode of ...         Ohno, S.
#
#   reference                           doi  year publication_database  ...  \
# 0       NaN     10.1161/CIRCEP.112.970517  2012               PubMed  ...
# 1       NaN    10.1016/j.jacc.2011.01.026  2011               PubMed  ...
# 2       NaN   10.1016/j.jacep.2020.03.006  2020               PubMed  ...
# 3       NaN      10.1253/circj.cj-12-1460  2013               PubMed  ...
# 4       NaN  10.1371/journal.pone.0131517  2015               PubMed  ...
#
#   treatment_taken::Implantable cardioverter-defibrillator  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#   treatment_taken::Left cardiac sympathetic denervation  \
# 0                                                NaN
# 1                                                0.0
# 2                                                NaN
# 3                                                0.0
# 4                                                NaN
#
#   treatment_taken::Verapamil  effective::Beta blocker  \
# 0                        NaN                      NaN
# 1                        0.0                      0.0
# 2                        NaN                      NaN
# 3                        0.0                      NaN
# 4                        NaN                      NaN
#
#   effective::Catheter ablation  effective::Enalapril effective::Flecainide  \
# 0                          NaN                   NaN                   NaN
# 1                          NaN                   NaN                   1.0
# 2                          NaN                   NaN                   NaN
# 3                          NaN                   NaN                   NaN
# 4                          NaN                   NaN                   NaN
#
#    effective::Implantable cardioverter-defibrillator  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    effective::Left cardiac sympathetic denervation effective::Verapamil
# 0                                              NaN                  NaN
# 1                                              NaN                  NaN
# 2                                              NaN                  NaN
# 3                                              NaN                  NaN
# 4                                              NaN                  NaN
#
# [5 rows x 159 columns]

# %%
figure_2 = config.figure2

# %%
reviewer_2_1 = config.reviewer2_1

# %%
colors = config.figure_palette

# %%
fig_dir = Path.cwd().parent / "figures" / config.version_for_dir / "analysis_13"

if not fig_dir.exists():
    fig_dir.mkdir(parents=True)
    print("Created directory:", fig_dir)
else:
    print("Directory exists:", fig_dir)
# Out:
# Directory exists: /Users/ac4294/dev/2024/cpvt_database_analysis/figures/0_3_3/analysis_13

# %%
data_sel = data[
    ["individual_id", "Catecholaminergic polymorphic ventricular tachycardia 1",
     "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1",
     "Syncope",
     "Sudden cardiac arrest",
     "Sudden cardiac death",
     "Polymorphic ventricular tachycardia",
     "Exercise/stress induced sudden cardiac arrest",
     "Exercise/stress induced polymorphic ventricular tachycardia",
     "Syncope exercise/stress induced",
     ]]

data_sel.head()
# Out:
#    individual_id  Catecholaminergic polymorphic ventricular tachycardia 1  \
# 0              1                                                1.0
# 1              2                                                1.0
# 2              3                                                1.0
# 3              4                                                1.0
# 4              5                                                1.0
#
#    age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                2.0
# 4                                               10.0
#
#    Syncope  Sudden cardiac arrest  Sudden cardiac death  \
# 0      NaN                    NaN                   NaN
# 1      0.0                    0.0                   NaN
# 2      1.0                    0.0                   NaN
# 3      0.0                    0.0                   NaN
# 4      1.0                    0.0                   NaN
#
#    Polymorphic ventricular tachycardia  \
# 0                                  1.0
# 1                                  1.0
# 2                                  1.0
# 3                                  1.0
# 4                                  NaN
#
#    Exercise/stress induced sudden cardiac arrest  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
#
#    Exercise/stress induced polymorphic ventricular tachycardia  \
# 0                                                1.0
# 1                                                1.0
# 2                                                1.0
# 3                                                1.0
# 4                                                NaN
#
#    Syncope exercise/stress induced
# 0                              NaN
# 1                              NaN
# 2                              1.0
# 3                              NaN
# 4                              NaN

# %%
# get only cpvt patients
print(len(data))

data_sel = data_sel[
    data_sel["Catecholaminergic polymorphic ventricular tachycardia 1"] == 1]
# make unique ids
data_sel = data_sel.drop_duplicates(subset="individual_id")

len(data_sel)
# Out:
# 1343
# 964

# %%
# plot age of onset for syncope and sudden cardiac arrest
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def get_data_df(df_org: pd.DataFrame, col: str, label_map: dict):
    df = df_org[[col,
                 "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"]].copy()
    df.columns = [col, "Age of onset"]
    df[col] = df[col].apply(
        lambda x: label_map.get(bool(x), x) if pd.notna(x) else "null"
    )
    return df


df_stat3 = get_data_df(data_sel, "Sudden cardiac death",
                       figure_2.panels["panel_c"].xticklabels)
df_stat3["Sudden cardiac death"].value_counts()
# Out:
# Sudden cardiac death
# null    964
# Name: count, dtype: int64

# %%
data_sync = get_data_df(data_sel, "Syncope",
                        figure_2.panels["panel_d"].xticklabels)
data_sync["Syncope"].value_counts()
# Out:
# Syncope
# Syncope       387
# null          339
# No Syncope    238
# Name: count, dtype: int64

# %%
sns.set_style("ticks")

DEFAULT_COLOR = sns.color_palette("husl", 9)[6]


def convert_pvalue_to_asterisks(pvalue):
    if pvalue <= 0.0001:
        return "***"
    elif pvalue <= 0.001:
        return "***"
    elif pvalue <= 0.01:
        return "**"
    elif pvalue <= 0.05:
        return "*"
    return ""


def add_significance_lines(p_value):
    p_str = convert_pvalue_to_asterisks(p_value)

    # draw line
    ax = plt.gca()

    y_range = plt.ylim()[1] - plt.ylim()[0]

    y_pos = plt.ylim()[1] + (y_range) * 0.05

    ax.plot(
        [0, 1],
        [y_pos, y_pos],
        color="black",
        lw=1
    )
    ax.plot(
        [0, 0],
        [y_pos, y_pos - 1],
        color="black",
        lw=1
    )
    ax.plot(
        [1, 1],
        [y_pos, y_pos - 1],
        color="black",
        lw=1
    )

    ax.text(
        0.5,
        y_pos,
        p_str,
        ha="center",
        va="center",
        fontsize=12,
        fontweight="bold"
    )


def make_boxplot(df: pd.DataFrame, *,
                 x: str,
                 y: str = "Age of onset",
                 output_file: str,
                 panel: FigureParams,
                 p_value: float = None
                 ):
    with plt.rc_context({
        "figure.figsize": panel.fig_size,
    }):
        order = panel.xticklabels.values()

        palette = {
            x_axis: color for x_axis, color in
            zip(order, sns.color_palette(colors.cat_palette, len(order)))
        }

        sns.boxplot(
            data=df[df[x] != "null"],
            x=x,
            y=y,
            fliersize=0,
            # hue=x,
            order=order,
            # hue_order=order,
            # palette={
            #     x_axis: color for x_axis, color in
            #     zip(order, sns.color_palette(colors.cat_palette, len(order)))
            # },
            fill=False,
            color="black",
            # linecolor=list(palette.values()),
            medianprops={"linewidth": 2},
        )

        sns.stripplot(
            data=df[df[x] != "null"],
            x=x,
            y=y,
            # color=colors.default_dot,
            hue=x,
            order=order,
            hue_order=order,
            palette=palette,
            # edgecolor="black",
            linewidth=0.25,
            alpha=colors.dot_alpha,
            size=3,
        )

        if p_value and p_value < 0.05:
            add_significance_lines(p_value)

        set_figure_size(
            panel
        )

        plt.savefig(fig_dir / output_file)
        plt.show()

# %%
from scipy.stats import mannwhitneyu
import pingouin as pg


def get_stats(df_stat: pd.DataFrame, col: str):
    df_stat = df_stat[df_stat[col] != "null"]

    categories = list(df_stat[col].unique())

    if len(categories) != 2:
        print(f"Skipping {col} due to {len(categories)} categories")
        return

    df_cat_1 = df_stat[df_stat[col] == categories[0]][["Age of onset"]].dropna()
    df_cat_2 = df_stat[df_stat[col] == categories[1]][["Age of onset"]].dropna()

    # _, p = mannwhitneyu(df_cat_1["Age of onset"], df_cat_2["Age of onset"])
    result_df = pg.mwu(df_cat_1["Age of onset"], df_cat_2["Age of onset"])

    result_df["Test direction"] = f"{categories[0]} vs {categories[1]}"

    print("Mann Whitney U test for", col)
    print(f"p value: {result_df["p-val"].iloc[0]:.10f}")

    summary_stats = df_stat.groupby(col).agg({
        "Age of onset": ["mean",
                         "median",
                         lambda x: x.quantile(0.25),
                         lambda x: x.quantile(0.75),
                         "count"]
    })

    summary_stats.columns = ["mean", "median", "q1", "q3", "count"]

    return summary_stats, result_df


syncope_stats = get_stats(data_sync, "Syncope")
syncope_stats[0]
# Out:
# Mann Whitney U test for Syncope
# p value: 0.0000164867
#                  mean  median    q1    q3  count
# Syncope
# No Syncope  23.270833    14.5  11.0  32.0     48
# Syncope     12.232564    10.0   7.0  14.0    234

# %%
make_boxplot(data_sync, x="Syncope",
             output_file="figure_2_panel_d.pdf",
             panel=figure_2.panels["panel_d"],
             p_value=syncope_stats[1]["p-val"].iloc[0]
             )
make_boxplot(data_sync, x="Syncope",
             output_file="reviewer2.question1.panel_b.pdf",
             panel=reviewer_2_1.panels["panel_b"],
             p_value=syncope_stats[1]["p-val"].iloc[0]
             )

# %%
make_boxplot(data_sync, x="Syncope",
             output_file="graphic_abstract_age_onset_vs_symptom.pdf",
             panel=get_config().graphic_abstract.panels[
                 "age_onset_vs_symptoms"],
             p_value=syncope_stats[1]["p-val"].iloc[0]
             )

# %%
# age of onset for sudden cardiac arrest
data_sca = get_data_df(data_sel, "Sudden cardiac arrest",
                       reviewer_2_1.panels["panel_c"].xticklabels)
data_sca["Sudden cardiac arrest"].value_counts()
# Out:
# Sudden cardiac arrest
# No SCA    435
# null      291
# SCA       238
# Name: count, dtype: int64

# %%
sca_stats = get_stats(data_sca, "Sudden cardiac arrest")
sca_stats[0]
# Out:
# Mann Whitney U test for Sudden cardiac arrest
# p value: 0.9121867493
#                             mean  median   q1    q3  count
# Sudden cardiac arrest
# No SCA                 14.725146    11.0  8.0  15.0    171
# SCA                    13.000394    11.0  7.0  15.0    127

# %%
make_boxplot(data_sca, x="Sudden cardiac arrest",
             output_file="reviewer2.question1.panel_c.pdf",
             panel=reviewer_2_1.panels["panel_c"],
             p_value=sca_stats[1]["p-val"].iloc[0]
             )

# %%
get_config().graphic_abstract.panels["age_onset_vs_symptoms"]
# Out:
# FigureParams(fig_size=(3.25, 4.0), title='Age of Onset vs\nIncidence of Syncope', xlabel=None, ylabel='Age of onset (years)', xticklabels={False: 'No Syncope', True: 'Syncope'}, yticklabels=None, x_label_fontsize=12, y_label_fontsize=12, title_fontsize=12, x_tick_fontsize=10, y_tick_fontsize=10, text_fontsize=10, panels=None)

# %%
pvt_df = get_data_df(data_sel, "Polymorphic ventricular tachycardia",
                     figure_2.panels["panel_c"].xticklabels)
pvt_df["Polymorphic ventricular tachycardia"].value_counts()
# Out:
# Polymorphic ventricular tachycardia
# PVT       411
# null      389
# No PVT    164
# Name: count, dtype: int64

# %%
pvt_stats = get_stats(pvt_df, "Polymorphic ventricular tachycardia")
pvt_stats[0]
# Out:
# Mann Whitney U test for Polymorphic ventricular tachycardia
# p value: 0.0005781095
#                                           mean  median      q1     q3  count
# Polymorphic ventricular tachycardia
# No PVT                               15.400000    13.5  10.000  19.75     30
# PVT                                  11.363482    10.0   6.375  13.00    224

# %%
make_boxplot(pvt_df, x="Polymorphic ventricular tachycardia",
             output_file="figure_2_panel_c.pdf",
             panel=figure_2.panels["panel_c"],
             p_value=pvt_stats[1]["p-val"].iloc[0]
             )
make_boxplot(pvt_df, x="Polymorphic ventricular tachycardia",
             output_file="reviewer2.question1.panel_a.pdf",
             panel=reviewer_2_1.panels["panel_a"],
             p_value=pvt_stats[1]["p-val"].iloc[0]
             )

# %% [markdown]
# ### Export Report

# %%
from analysis.eff_size import get_effect_size

# combine all the stats
all_stats = pd.concat(
    [
        pvt_stats[1].assign(symptom="PVT"),
        syncope_stats[1].assign(symptom="Syncope"),
        sca_stats[1].assign(symptom="SCA")
    ]
)

all_stats["effect_size (cliff)"] = all_stats["RBC"].apply(
    lambda x: get_effect_size(x, "cliff"))
all_stats["effect_size (vda)"] = all_stats["CLES"].apply(
    lambda x: get_effect_size(x, "vda"))

all_stats["p-val"] = all_stats["p-val"].round(4)
all_stats["CLES"] = all_stats["CLES"].round(4)
all_stats["RBC"] = all_stats["RBC"].round(4)

# reorder columns
all_stats = all_stats[[
    "U-val",
    "p-val",
    "RBC",
    "effect_size (cliff)",
    "CLES",
    "effect_size (vda)",
    "Test direction"
]].set_index("Test direction")

all_stats.head()
# Out:
#                          U-val   p-val     RBC effect_size (cliff)    CLES  \
# Test direction
# PVT vs No PVT           2061.5  0.0006 -0.3865              medium  0.3068
# No Syncope vs Syncope   7830.0  0.0000  0.3942              medium  0.6971
# No SCA vs SCA          10940.0  0.9122  0.0075                None  0.5038
#
#                       effect_size (vda)
# Test direction
# PVT vs No PVT                    medium
# No Syncope vs Syncope            medium
# No SCA vs SCA                      None

# %%
from analysis.write_report import write_sections_to_pdf, PdfSection
from reportlab.lib.pagesizes import A4
from reportlab.pdfgen import canvas

# report
pdf_name = fig_dir / "age_onset_vs_disease.pdf"

pdf_elements: list[PdfSection] = [
    PdfSection(
        section="Mann Whitney U test",
        stuff=[
            all_stats
        ]
    ),
    PdfSection(
        section="polymorphic vt",
        stuff=[
            pvt_stats[0]
        ]
    ),
    PdfSection(
        section="syncope",
        stuff=[
            syncope_stats[0]
        ]
    ),
    PdfSection(
        section="sudden cardiac arrest",
        stuff=[
            sca_stats[0]
        ]
    )
]

# Create PDF and write content
c = canvas.Canvas(str(pdf_name), pagesize=A4)
write_sections_to_pdf(c, pdf_elements)
c.save()

print(f"PDF saved to {pdf_name}")
# Out:
# PDF saved to /Users/alex/dev/marks/2024/cpvt_database_analysis/figures/0_3_3/analysis_13/age_onset_vs_disease.pdf

# %% [markdown]
# # See Syncope and Sudden Cardiac Arrest
#
# It was pointed out that even in patients who reported syncope - they may have had sudden cardiac arrest, but it was reported
# as syncope since they fainted.

# %%
data_sny_sca = data_sel[[
    "individual_id",
    "Syncope",
    "Sudden cardiac arrest"
]].copy()
data_sny_sca.drop_duplicates(subset="individual_id", inplace=True)

data_sny_sca = data_sny_sca[
    data_sny_sca["Syncope"].notna() & data_sny_sca[
        "Sudden cardiac arrest"].notna()
    ]

print(data_sny_sca.shape)
data_sny_sca = data_sny_sca.map(lambda x: "Yes" if x == 1 else "No")

data_sny_sca.head()
# Out:
# (534, 3)
#    individual_id Syncope Sudden cardiac arrest
# 1             No      No                    No
# 2             No     Yes                    No
# 3             No      No                    No
# 4             No     Yes                    No
# 27            No      No                    No

# %%
data_sny_sca["Syncope"].value_counts()
# Out:
# Syncope
# Yes    297
# No     237
# Name: count, dtype: int64

# %%
data_sny_sca["Sudden cardiac arrest"].value_counts()
# Out:
# Sudden cardiac arrest
# No     414
# Yes    120
# Name: count, dtype: int64

# %%
# create Contingency table
sca_vs_syncope = pd.crosstab(data_sny_sca["Syncope"],
                             data_sny_sca["Sudden cardiac arrest"])
sca_vs_syncope = sca_vs_syncope.rename(
    columns={
        "No": "No Sudden Cardiac Arrest",
        "Yes": "Sudden Cardiac Arrest"
    },
    index={
        "No": "No Syncope",
        "Yes": "Syncope"
    },
)
# remove levels
sca_vs_syncope.columns.name = None
sca_vs_syncope.index.name = "Syncope / Sudden Cardiac Arrest"

sca_vs_syncope.to_csv(Path.cwd().parent / "data" / "fisher_sca_vs_syncope.csv")

sca_vs_syncope
# Out:
#                                  No Sudden Cardiac Arrest  \
# Syncope / Sudden Cardiac Arrest
# No Syncope                                            183
# Syncope                                               231
#
#                                  Sudden Cardiac Arrest
# Syncope / Sudden Cardiac Arrest
# No Syncope                                          54
# Syncope                                             66

# %%
sca_vs_syncope["No Sudden Cardiac Arrest"].sum()
# Out:
# 414

# %%
sca_vs_syncope["Sudden Cardiac Arrest"].sum()
# Out:
# 120

# %%
from scipy.stats import fisher_exact, chi2_contingency

oddsratio, pvalue = fisher_exact(sca_vs_syncope)

print("Odds ratio (F):", oddsratio)
print("p-value (F):", pvalue)

chi2, p, dof, ex = chi2_contingency(sca_vs_syncope)

print("Chi2:", chi2)
print("p-value (Chi2):", p)
# Out:
# Odds ratio (F): 0.9682539682539683
# p-value (F): 0.917029908365811
# Chi2: 0.002541173367627172
# p-value (Chi2): 0.9597956260369604

# %% [markdown]
# # Syncope vs Sudden Cardiac Arrest
#
# Is there a difference in  age of onset and incidence of combination of syncope and sudden cardiac arrest?

# %%
data_sny_sca_age = data_sel[[
    "individual_id",
    "Syncope",
    "Sudden cardiac arrest",
    "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"
]].copy()
# create groups based on syncope and sudden cardiac arrest (bool add)
data_sny_sca_age["group_ssca"] = data_sny_sca_age["Syncope"] * 2 + \
                                 data_sny_sca_age["Sudden cardiac arrest"]
data_sny_sca_age["group_ssca"] = data_sny_sca_age["group_ssca"].map({
    0: "No Syncope, No Sudden Cardiac Arrest",
    1: "No Syncope, Sudden Cardiac Arrest",
    2: "Syncope, No Sudden Cardiac Arrest",
    3: "Syncope, Sudden Cardiac Arrest"
})

data_sny_sca_age["group_ssca"].value_counts()
# Out:
# group_ssca
# Syncope, No Sudden Cardiac Arrest       231
# No Syncope, No Sudden Cardiac Arrest    183
# Syncope, Sudden Cardiac Arrest           66
# No Syncope, Sudden Cardiac Arrest        54
# Name: count, dtype: int64

# %%
# kruskal wallis test
from scipy.stats import kruskal
from scikit_posthocs import posthoc_dunn

# %%
data_sny_sca_age = data_sny_sca_age.dropna(subset=[
    "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1",
    "group_ssca"])
data_sny_sca_age.head()
# Out:
#     individual_id  Syncope  Sudden cardiac arrest  \
# 3               4      0.0                    0.0
# 4               5      1.0                    0.0
# 27             28      0.0                    0.0
# 32             33      1.0                    0.0
# 35             36      1.0                    0.0
#
#     age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1  \
# 3                                                 2.0
# 4                                                10.0
# 27                                                6.0
# 32                                                6.0
# 35                                               11.0
#
#                               group_ssca
# 3   No Syncope, No Sudden Cardiac Arrest
# 4      Syncope, No Sudden Cardiac Arrest
# 27  No Syncope, No Sudden Cardiac Arrest
# 32     Syncope, No Sudden Cardiac Arrest
# 35     Syncope, No Sudden Cardiac Arrest

# %%
data_sny_sca_age["group_ssca"].value_counts()
# Out:
# group_ssca
# Syncope, No Sudden Cardiac Arrest       146
# Syncope, Sudden Cardiac Arrest           44
# No Syncope, No Sudden Cardiac Arrest     24
# No Syncope, Sudden Cardiac Arrest        24
# Name: count, dtype: int64

# %%
# kruskal wallis test
groups = [
    data_sny_sca_age[data_sny_sca_age["group_ssca"] == group][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"]
    for group in data_sny_sca_age["group_ssca"].unique()
]

stat_kw, p_kw = kruskal(
    *groups
)
# don't print in scientific notation
print(f"Kruskal Wallis test: H = {stat_kw:.2f}, p = {p_kw:.10f}")
# Out:
# Kruskal Wallis test: H = 22.55, p = 0.0000501997

# %%
# posthoc dunn
posthoc = posthoc_dunn(
    data_sny_sca_age,
    val_col="age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1",
    group_col="group_ssca",
    p_adjust="bonferroni"
)

posthoc
# Out:
#                                       No Syncope, No Sudden Cardiac Arrest  \
# No Syncope, No Sudden Cardiac Arrest                              1.000000
# No Syncope, Sudden Cardiac Arrest                                 1.000000
# Syncope, No Sudden Cardiac Arrest                                 0.001544
# Syncope, Sudden Cardiac Arrest                                    0.000448
#
#                                       No Syncope, Sudden Cardiac Arrest  \
# No Syncope, No Sudden Cardiac Arrest                           1.000000
# No Syncope, Sudden Cardiac Arrest                              1.000000
# Syncope, No Sudden Cardiac Arrest                              0.061663
# Syncope, Sudden Cardiac Arrest                                 0.015372
#
#                                       Syncope, No Sudden Cardiac Arrest  \
# No Syncope, No Sudden Cardiac Arrest                           0.001544
# No Syncope, Sudden Cardiac Arrest                              0.061663
# Syncope, No Sudden Cardiac Arrest                              1.000000
# Syncope, Sudden Cardiac Arrest                                 1.000000
#
#                                       Syncope, Sudden Cardiac Arrest
# No Syncope, No Sudden Cardiac Arrest                        0.000448
# No Syncope, Sudden Cardiac Arrest                           0.015372
# Syncope, No Sudden Cardiac Arrest                           1.000000
# Syncope, Sudden Cardiac Arrest                              1.000000

# %%
# get what the actual avg and p values are
def get_stat_dunn(df_ref: pd.DataFrame, df_posthoc: pd.DataFrame, group1: str,
                  group2: str):
    padj = df_posthoc.loc[group1, group2]
    med_g1 = df_ref[df_ref["group_ssca"] == group1][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].median()
    med_g2 = df_ref[df_ref["group_ssca"] == group2][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].median()

    q1_g1 = df_ref[df_ref["group_ssca"] == group1][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].quantile(
        0.25)
    q3_g1 = df_ref[df_ref["group_ssca"] == group1][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].quantile(
        0.75)

    q1_g2 = df_ref[df_ref["group_ssca"] == group2][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].quantile(
        0.25)
    q3_g2 = df_ref[df_ref["group_ssca"] == group2][
        "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].quantile(
        0.75)

    print(
        f"Group 1: {group1} Median: {med_g1}, IQR: {q1_g1}-{q3_g1} ({q3_g1 - q1_g1}), n={len(df_ref[df_ref['group_ssca'] == group1])}")
    print(
        f"Group 2: {group2} Median: {med_g2}, IQR: {q1_g2}-{q3_g2} ({q3_g2 - q1_g2}), n={len(df_ref[df_ref['group_ssca'] == group2])}")

    print(f"p-adj: {padj}")


for g1 in posthoc.columns:
    for g2 in posthoc.index:
        if g1 == g2:
            continue
        print(f"Comparing {g1} and {g2}")
        get_stat_dunn(data_sny_sca_age, posthoc, g1, g2)
        print()
# Out:
# Comparing No Syncope, No Sudden Cardiac Arrest and No Syncope, Sudden Cardiac Arrest
# Group 1: No Syncope, No Sudden Cardiac Arrest Median: 29.5, IQR: 11.25-44.75 (33.5), n=24
# Group 2: No Syncope, Sudden Cardiac Arrest Median: 13.5, IQR: 11.0-19.0 (8.0), n=24
# p-adj: 1.0
#
# Comparing No Syncope, No Sudden Cardiac Arrest and Syncope, No Sudden Cardiac Arrest
# Group 1: No Syncope, No Sudden Cardiac Arrest Median: 29.5, IQR: 11.25-44.75 (33.5), n=24
# Group 2: Syncope, No Sudden Cardiac Arrest Median: 10.0, IQR: 8.0-14.0 (6.0), n=146
# p-adj: 0.001543643570067598
#
# Comparing No Syncope, No Sudden Cardiac Arrest and Syncope, Sudden Cardiac Arrest
# Group 1: No Syncope, No Sudden Cardiac Arrest Median: 29.5, IQR: 11.25-44.75 (33.5), n=24
# Group 2: Syncope, Sudden Cardiac Arrest Median: 8.5, IQR: 6.0-14.0 (8.0), n=44
# p-adj: 0.00044821976291462094
#
# Comparing No Syncope, Sudden Cardiac Arrest and No Syncope, No Sudden Cardiac Arrest
# Group 1: No Syncope, Sudden Cardiac Arrest Median: 13.5, IQR: 11.0-19.0 (8.0), n=24
# Group 2: No Syncope, No Sudden Cardiac Arrest Median: 29.5, IQR: 11.25-44.75 (33.5), n=24
# p-adj: 1.0
#
# Comparing No Syncope, Sudden Cardiac Arrest and Syncope, No Sudden Cardiac Arrest
# Group 1: No Syncope, Sudden Cardiac Arrest Median: 13.5, IQR: 11.0-19.0 (8.0), n=24
# Group 2: Syncope, No Sudden Cardiac Arrest Median: 10.0, IQR: 8.0-14.0 (6.0), n=146
# p-adj: 0.06166308202079999
#
# Comparing No Syncope, Sudden Cardiac Arrest and Syncope, Sudden Cardiac Arrest
# Group 1: No Syncope, Sudden Cardiac Arrest Median: 13.5, IQR: 11.0-19.0 (8.0), n=24
# Group 2: Syncope, Sudden Cardiac Arrest Median: 8.5, IQR: 6.0-14.0 (8.0), n=44
# p-adj: 0.015371691827789562
#
# Comparing Syncope, No Sudden Cardiac Arrest and No Syncope, No Sudden Cardiac Arrest
# Group 1: Syncope, No Sudden Cardiac Arrest Median: 10.0, IQR: 8.0-14.0 (6.0), n=146
# Group 2: No Syncope, No Sudden Cardiac Arrest Median: 29.5, IQR: 11.25-44.75 (33.5), n=24
# p-adj: 0.001543643570067598
#
# Comparing Syncope, No Sudden Cardiac Arrest and No Syncope, Sudden Cardiac Arrest
# Group 1: Syncope, No Sudden Cardiac Arrest Median: 10.0, IQR: 8.0-14.0 (6.0), n=146
# Group 2: No Syncope, Sudden Cardiac Arrest Median: 13.5, IQR: 11.0-19.0 (8.0), n=24
# p-adj: 0.06166308202079999
#
# Comparing Syncope, No Sudden Cardiac Arrest and Syncope, Sudden Cardiac Arrest
# Group 1: Syncope, No Sudden Cardiac Arrest Median: 10.0, IQR: 8.0-14.0 (6.0), n=146
# Group 2: Syncope, Sudden Cardiac Arrest Median: 8.5, IQR: 6.0-14.0 (8.0), n=44
# p-adj: 1.0
#
# Comparing Syncope, Sudden Cardiac Arrest and No Syncope, No Sudden Cardiac Arrest
# Group 1: Syncope, Sudden Cardiac Arrest Median: 8.5, IQR: 6.0-14.0 (8.0), n=44
# Group 2: No Syncope, No Sudden Cardiac Arrest Median: 29.5, IQR: 11.25-44.75 (33.5), n=24
# p-adj: 0.00044821976291462094
#
# Comparing Syncope, Sudden Cardiac Arrest and No Syncope, Sudden Cardiac Arrest
# Group 1: Syncope, Sudden Cardiac Arrest Median: 8.5, IQR: 6.0-14.0 (8.0), n=44
# Group 2: No Syncope, Sudden Cardiac Arrest Median: 13.5, IQR: 11.0-19.0 (8.0), n=24
# p-adj: 0.015371691827789562
#
# Comparing Syncope, Sudden Cardiac Arrest and Syncope, No Sudden Cardiac Arrest
# Group 1: Syncope, Sudden Cardiac Arrest Median: 8.5, IQR: 6.0-14.0 (8.0), n=44
# Group 2: Syncope, No Sudden Cardiac Arrest Median: 10.0, IQR: 8.0-14.0 (6.0), n=146
# p-adj: 1.0

# %%
order_ssca = [
    "No Syncope, No Sudden Cardiac Arrest",
    "No Syncope, Sudden Cardiac Arrest",
    "Syncope, No Sudden Cardiac Arrest",
    "Syncope, Sudden Cardiac Arrest"
]

with plt.rc_context({
    "font.size": 12,
    "figure.figsize": (10, 6),
}):
    sns.set_style("ticks")
    # boxplots
    sns.boxplot(
        data=data_sny_sca_age,
        y="group_ssca",
        x="age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1",
        showfliers=False,
        order=order_ssca,
        # hue_order=order_ssca,
        # hue="group_ssca",
        legend=False,
        # palette=sns.color_palette(colors.cat_palette, len(order_ssca)),
        color="black",
        fill=False,
        medianprops=colors.box_median_props
    )
    sns.stripplot(
        data=data_sny_sca_age,
        y="group_ssca",
        x="age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1",
        color="black",
        alpha=0.75,
        size=3,
        linewidth=0.25,
        order=order_ssca,
        hue_order=order_ssca,
        hue="group_ssca",
        palette=sns.color_palette(colors.cat_palette, len(order_ssca)),
    )
    # plt.xticks(rotation=45)
    plt.xlabel("Age of onset")
    plt.ylabel("Group")

    max_x = data_sny_sca_age[
                "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].max() + .05 * \
            data_sny_sca_age[
                "age_of_onset::Catecholaminergic polymorphic ventricular tachycardia 1"].max()
    prev_x_lim = plt.xlim()

    added_stars = set()
    # add p-values
    for g1 in posthoc.columns:
        for g2 in posthoc.index:

            star_key = tuple(sorted([g1, g2]))

            if star_key in added_stars:
                continue

            added_stars.add(star_key)

            if g1 == g2:
                continue
            pvalue = posthoc.loc[g2, g1]
            pvalue_str = convert_pvalue_to_asterisks(pvalue)

            if not pvalue_str:
                print("Skipping", g1, g2)
                continue

            print(f"Adding {pvalue_str} between {g1} and {g2}")

            y_pos = order_ssca.index(g1)
            y_pos2 = order_ssca.index(g2)

            # draw line
            ax = plt.gca()

            ax.plot(
                [max_x, max_x],
                [y_pos, y_pos2],
                color="black",
                lw=1
            )
            ax.plot(
                [max_x, max_x - 1],
                [y_pos, y_pos],
                color="black",
                lw=1
            )
            ax.plot(
                [max_x, max_x - 1],
                [y_pos2, y_pos2],
                color="black",
                lw=1
            )
            star_loc = (y_pos + y_pos2) / 2

            ax.text(
                max_x + 0.1,
                star_loc,
                pvalue_str,
                ha="left",
                va="center",
                fontsize=12,
                fontweight="bold"
            )

            max_x += 4

    sns.despine()

    # only allow x ticks to go up to previous x limit
    plt.xticks(np.arange(0, prev_x_lim[1] + 1, 10))

    plt.tight_layout()

    plt.savefig(
        fig_dir / "reviewer2.question1.age_vs_syncope_and_sudden_cardiac_arrest.png")

    plt.show()
# Out:
# Skipping No Syncope, No Sudden Cardiac Arrest No Syncope, Sudden Cardiac Arrest
# Adding ** between No Syncope, No Sudden Cardiac Arrest and Syncope, No Sudden Cardiac Arrest
# Adding *** between No Syncope, No Sudden Cardiac Arrest and Syncope, Sudden Cardiac Arrest
# Skipping No Syncope, Sudden Cardiac Arrest Syncope, No Sudden Cardiac Arrest
# Adding * between No Syncope, Sudden Cardiac Arrest and Syncope, Sudden Cardiac Arrest
# Skipping Syncope, No Sudden Cardiac Arrest Syncope, Sudden Cardiac Arrest
